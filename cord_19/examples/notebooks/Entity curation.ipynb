# %% [markdown]
# # Interactive curation of  entity occurrence data
#
# In this notebook we will illustrate how the curation application included in the `cord_19` package can be used to perform interactive curation of named entity occurrence data.
#
# The input data for this notebook contains the named entities extracted from a small selection of 20 articles from the dataset of [COVID-19 Open Research Dataset Challenge](https://www.kaggle.com/allen-institute-for-ai/CORD-19-research-challenge).

# %%
import json
import zipfile

import pandas as pd

from cord_19.utils import (generate_curation_table,
                           link_ontology)
from cord_19.apps.curation_app import curation_app

# %% [markdown]
# ## Preparing entity occurrence data
#
# The input dataset contains occurrences of different terms in paragraphs of scientific articles from the CORD-19 dataset previously extracted by means of a Named Entity Recognition (NER) model.

# %%
data = pd.read_csv("../data/Glucose_risk_20_papers.csv")

# %%
# %%time
print("Decompressing the input data file...")
with zipfile.ZipFile("../data/Glucose_risk_3000_papers.csv.zip", 'r') as zip_ref:
    zip_ref.extractall("../data/")
data = pd.read_csv("../data/Glucose_risk_3000_papers.csv")
print("Done.")
# Out:
# Decompressing the input data file...
# Done.
# CPU times: user 2.32 s, sys: 302 ms, total: 2.62 s
# Wall time: 2.67 s

# %% [markdown]
# On the first preparation step, we group and aggregate the input data by unique entities.

# %%
data["entity"] = data["entity"].apply(lambda x: x.lower())

# %%
# %%time
print("Prepating curatation data...")
curation_input_table, factor_counts = generate_curation_table(data)
print("Done.")
# Out:
# Prepating curatation data...
# Cleaning up the entities...
# Aggregating occurrences of entities....
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     970                 try:
# --> 971                     result = self._aggregate_multiple_funcs([func], _axis=self.axis)
#     972
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _axis)
#     525                 try:
# --> 526                     new_res = colg.aggregate(arg)
#     527                 except (TypeError, DataError):
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     245             func = maybe_mangle_lambdas(func)
# --> 246             ret = self._aggregate_multiple_funcs(func)
#     247             if relabeling:
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg)
#     318                 obj._selection = name
# --> 319             results[base.OutputKey(label=name, position=idx)] = obj.aggregate(func)
#     320
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     259             try:
# --> 260                 return self._python_agg_general(
#     261                     func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, engine, engine_kwargs, *args, **kwargs)
#    1082                     # if this function is invalid for this dtype, we will ignore it.
# -> 1083                     result, counts = self.grouper.agg_series(obj, f)
#    1084                 except TypeError:
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, engine, engine_kwargs, *args, **kwargs)
#     643         try:
# --> 644             return self._aggregate_series_fast(obj, func)
#     645         except ValueError as err:
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#     668         grouper = libreduction.SeriesGrouper(obj, func, group_index, ngroups, dummy)
# --> 669         result, counts = grouper.get_result()
#     670         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction._BaseGrouper._apply_to_group()
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1059         if engine != "numba":
# -> 1060             f = lambda x: func(x, *args, **kwargs)
#    1061
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/cord_19/utils.py in <lambda>(x)
#     168     occurence_data = raw_data.groupby(term_column).aggregate(
# --> 169         lambda x: aggregation_function(x))
#     170
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/cord_19/utils.py in <lambda>(x)
#     240             term_filter=lambda x: has_min_length(x, 3),
# --> 241             aggregation_function=lambda x: aggregate_cord_entities(x, factors),
#     242             mention_filter=lambda data: ~data["section"].apply(
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/cord_19/utils.py in aggregate_cord_entities(x, factors)
#     190     result = {
# --> 191         "entity_type": list(x.entity_type)
#     192     }
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#
# AttributeError: 'Series' object has no attribute 'entity_type'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/cord_19/utils.py in generate_curation_table(data)
#     269
#     270 def generate_curation_table(data):
# --> 271     data, counts = prepare_occurrence_data(data)
#     272     data = data.reset_index()
#     273     data["paper_frequency"] = data[
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/cord_19/utils.py in prepare_occurrence_data(mentions_df, mentions_path, occurrence_data_path, factors, factor_counts_path)
#     233             lambda x: ":".join([x.split(":")[0], x.split(":")[1]]))
#     234         mentions = mentions.rename(columns={"occurrence": "paragraph"})
# --> 235         occurrence_data, counts = mentions_to_occurrence(
#     236             mentions,
#     237             term_column="entity",
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/cord_19/utils.py in mentions_to_occurrence(raw_data, term_column, factor_columns, term_cleanup, term_filter, mention_filter, aggregation_function, dump_prefix)
#     166         aggregation_function = set
#     167
# --> 168     occurence_data = raw_data.groupby(term_column).aggregate(
#     169         lambda x: aggregation_function(x))
#     170
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     985                     # catch exception from line 969
#     986                     # (Series does not have attribute "columns"), see GH 35246
# --> 987                     result = self._aggregate_frame(func)
#     988
#     989         if relabeling:
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _aggregate_frame(self, func, *args, **kwargs)
#    1181                 result[name] = fres
#    1182
# -> 1183         return self._wrap_frame_output(result, obj)
#    1184
#    1185     def _aggregate_item_by_item(self, func, *args, **kwargs) -> DataFrame:
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _wrap_frame_output(self, result, obj)
#    1688
#    1689         if self.axis == 0:
# -> 1690             return self.obj._constructor(
#    1691                 result, index=obj.columns, columns=result_index
#    1692             ).T
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      81
#      82         # don't force copy because getting jammed in an ndarray anyway
# ---> 83         arrays = _homogenize(arrays, index, dtype)
#      84
#      85         columns = ensure_index(columns)
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     349                     val = dict(val)
#     350                 val = lib.fast_multiget(val, oindex._values, default=np.nan)
# --> 351             val = sanitize_array(
#     352                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     353             )
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     510                 subarr = np.array(data, dtype=object, copy=copy)
#     511
# --> 512         if is_object_dtype(subarr.dtype) and not is_object_dtype(dtype):
#     513             inferred = lib.infer_dtype(subarr, skipna=False)
#     514             if inferred in {"interval", "period"}:
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_object_dtype(arr_or_dtype)
#     219     False
#     220     """
# --> 221     return _is_dtype_type(arr_or_dtype, classes(np.object_))
#     222
#     223
#
# ~/opt/anaconda3/envs/bbg/lib/python3.8/site-packages/pandas/core/dtypes/common.py in _is_dtype_type(arr_or_dtype, condition)
#    1613     """
#    1614     if arr_or_dtype is None:
# -> 1615         return condition(type(None))
#    1616
#    1617     # fastpath
#
# KeyboardInterrupt:

# %% [markdown]
# The resulting dataframe contains a row per unique named entity together with the following occurrence data:
# - sets of paragraphs, papers, sections, where the corresponding entity is mentioned (`paper`, `section`, `paragraph` columns);
# - number of total occurrences (the `raw_frequency` column);
# - number of unique papers where it occurs (the `paper_frequency` column);
# - entity type assigned by the NER model (the `entity_type` column).

# %%
curation_input_table
# Out:
#                 entity entity_type  \
# 0               4e-bp1     PROTEIN
# 1                  ace     PROTEIN
# 2                ace-2     PROTEIN
# 3                 ace2     PROTEIN
# 4        ace2 receptor     PROTEIN
# ..                 ...         ...
# 263  viral replication     PATHWAY
# 264              virus    ORGANISM
# 265        virus entry     PATHWAY
# 266            viruses    ORGANISM
# 267           vomiting     DISEASE
#
#                                              paragraph  \
# 0    [214924:The Interplay Between Covid-19 And Amp...
# 1    [179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
# 2    [179426:Role Of Antidiabetic Drugs In Current ...
# 3    [184360:Caption:71, 184360:Combined Therapeuti...
# 4        [211373:Introduction:5, 214924:Conclusion:28]
# ..                                                 ...
# 263  [214924:The Immune Response To Sars-Cov-2 ::: ...
# 264  [214924:Introduction:3, 184360:Gliptins ::: Th...
# 265  [184360:Anti-Dpp4 Vaccine ::: Therapeutic Pote...
# 266  [197804:Introduction:2, 211125:Discussion:25, ...
# 267  [179426:Glycemic Control ::: Special Aspects O...
#
#                                                  paper  \
# 0                                             [214924]
# 1                             [214924, 179426, 184360]
# 2                                             [179426]
# 3    [184360, 211373, 211125, 214924, 160564, 17942...
# 4                                     [214924, 211373]
# ..                                                 ...
# 263                                           [214924]
# 264           [184360, 211373, 214924, 179426, 197804]
# 265                                   [184360, 211373]
# 266                   [211125, 160564, 214924, 197804]
# 267                                           [179426]
#
#                                                section  paper_frequency  \
# 0    [214924:The Interplay Between Covid-19 And Amp...                1
# 1    [179426:Role Of Ace/Arbs , 214924:The Protecti...                3
# 2    [179426:Role Of Antidiabetic Drugs In Current ...                1
# 3    [214924:The Immune Response To Sars-Cov-2 , 19...                7
# 4             [214924:Conclusion, 211373:Introduction]                2
# ..                                                 ...              ...
# 263  [214924:The Immune Response To Sars-Cov-2 , 21...                1
# 264  [184360:Abstract, 214924:Abstract, 214924:The ...                5
# 265  [184360:Abstract, 184360:Combined Therapeutic ...                2
# 266  [214924:The Immune Response To Sars-Cov-2 , 21...                4
# 267  [179426:Glycemic Control , 179426:Measures For...                1
#
#      raw_frequency
# 0                2
# 1                9
# 2               10
# 3               79
# 4                2
# ..             ...
# 263              2
# 264             24
# 265              5
# 266              6
# 267              2
#
# [268 rows x 7 columns]

# %% [markdown]
# The second output of the data preparation step outputs the counts of different instances of occurrence factors: number of distinct papers/sections/paragraphs in the input corpus.

# %%
factor_counts
# Out:
# {'paper': 20, 'section': 108, 'paragraph': 286}

# %% [markdown]
# ## Loading the NCIT ontology linking data

# %% [markdown]
# To group synonymical entities in the previously extracted table (e.g. `ace2`, `ace-2`, `angiotensin-converting enzyme 2`), as well as assign additional semantics to these entities (e.g. human-readable definition, taxonomy, etc), we peform further _linking_ of the entities to the terms from the [NCIT ontology](https://ncithesaurus.nci.nih.gov/ncitbrowser/).
#
# To perform such ontology linking, we load some additional (pre-computed) data.

# %%
# %%time
print("Loading the ontology linking data...")
    
print("\tDecompressing the input data file...")
with zipfile.ZipFile("../data/NCIT_ontology_linking_3000_papers.csv.zip", 'r') as zip_ref:
    zip_ref.extractall("../data/")

print("\tLoading the linking dataframe in memory...")
ontology_linking = pd.read_csv("../data/NCIT_ontology_linking_3000_papers.csv")

print("\tLoading ontology type mapping...")
with open("../data/NCIT_type_mapping.json", "rb") as f:
    type_mapping = json.load(f)
print("Done.")
# Out:
# Loading the ontology linking data...
# 	Decompressing the input data file...
# 	Loading the linking dataframe in memory...
# 	Loading ontology type mapping...
# Done.
# CPU times: user 1.04 s, sys: 155 ms, total: 1.2 s
# Wall time: 1.23 s

# %% [markdown]
# The ontology linking table contains the following columns:
# - `mention`
# - `concept`
# - `uid`
# - `definition`
# - `semantic_type`
# - `taxonomy`

# %%
ontology_linking
# Out:
#                 mention                           concept  \
# 0             protein-d             lithostathine-1-alpha
# 1             pulmonary                         pulmonary
# 2                  host                              host
# 3                  sp-d  surfactant protein d measurement
# 4       innate response            communication response
# ...                 ...                               ...
# 160780      pparα-knock                 pericardial knock
# 160781     capacity.[47                          capacity
# 160782      obesity.[48                    obesity, ctcae
# 160783         mice.[49                             mouse
# 160784         life.[55                              life
#
#                                                 uid  \
# 0       http://purl.obolibrary.org/obo/NCIT_C131324
# 1        http://purl.obolibrary.org/obo/NCIT_C13304
# 2        http://purl.obolibrary.org/obo/NCIT_C66819
# 3       http://purl.obolibrary.org/obo/NCIT_C111322
# 4        http://purl.obolibrary.org/obo/NCIT_C82658
# ...                                             ...
# 160780  http://purl.obolibrary.org/obo/NCIT_C168024
# 160781   http://purl.obolibrary.org/obo/NCIT_C25443
# 160782   http://purl.obolibrary.org/obo/NCIT_C55334
# 160783   http://purl.obolibrary.org/obo/NCIT_C14238
# 160784  http://purl.obolibrary.org/obo/NCIT_C142142
#
#                                                definition  \
# 0       Lithostathine-1-alpha (166 aa, ~19 kDa) is enc...
# 1       Relating to the lungs as the intended site of ...
# 2       An organism that nourishes and supports anothe...
# 3       The determination of the amount of surfactant ...
# 4       A statement (either spoken or written) that is...
# ...                                                   ...
# 160780  An auscultated finding describing an early dia...
# 160781  The amount that can be contained.  It can refe...
# 160782  A disorder characterized by having a high amou...
# 160783  Any of numerous species of small rodents belon...
# 160784  The biochemical phenomenon that distinguishes ...
#
#                           semantic_type  \
# 0       Amino Acid, Peptide, or Protein
# 1                   Qualitative Concept
# 2                              Organism
# 3                  Laboratory Procedure
# 4                       Social Behavior
# ...                                 ...
# 160780                          Finding
# 160781             Quantitative Concept
# 160782                          Finding
# 160783                           Mammal
# 160784                Conceptual Entity
#
#                                                  taxonomy
# 0       [('http://purl.obolibrary.org/obo/NCIT_C18466'...
# 1       [('http://purl.obolibrary.org/obo/NCIT_C13442'...
# 2       [('http://purl.obolibrary.org/obo/NCIT_C14376'...
# 3       [('http://purl.obolibrary.org/obo/NCIT_C64430'...
# 4       [('http://purl.obolibrary.org/obo/NCIT_C16452'...
# ...                                                   ...
# 160780  [('http://purl.obolibrary.org/obo/NCIT_C167450...
# 160781  [('http://purl.obolibrary.org/obo/NCIT_C25447'...
# 160782  [('http://purl.obolibrary.org/obo/NCIT_C143174...
# 160783  [('http://purl.obolibrary.org/obo/NCIT_C14246'...
# 160784  [('http://purl.obolibrary.org/obo/NCIT_C20181'...
#
# [160785 rows x 6 columns]

# %% [markdown]
# ## Running the curation app

# %%
default_term_filters = ["glucose"]

# %%
curation_app.set_default_terms_to_include(default_term_filters)
curation_app.set_table(curation_input_table.copy())
curation_app.set_ontology_linking_callback(lambda x: link_ontology(ontology_linking, type_mapping, x))

# Try setting `mode="external"` to open the app in the new tab
curation_app.run(port=8070, mode="inline")
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8070/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Merging the occurrence data with the ontology linking...

# %% [markdown]
# ## Extracting curated data

# %%
curated_occurrence_data = curation_app.get_curated_table()

# %%
curated_occurrence_data
# Out:
#                    aggregated_entities  \
# entity
# 4e-bp1                        [4e-bp1]
# ace                              [ace]
# ace2                            [ace2]
# ace2 receptor          [ace2 receptor]
# ace2 receptors        [ace2 receptors]
# ...                                ...
# viral infection      [viral infection]
# viral infections    [viral infections]
# viral replication  [viral replication]
# virus                 [virus, viruses]
# vomiting                    [vomiting]
#
#                                                            paragraph  \
# entity
# 4e-bp1             [214924:The Interplay Between Covid-19 And Amp...
# ace                [179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
# ace2               [184360:Caption:71, 184360:Combined Therapeuti...
# ace2 receptor          [211373:Introduction:5, 214924:Conclusion:28]
# ace2 receptors     [211125:Discussion:25, 214924:Angiotensin-Conv...
# ...                                                              ...
# viral infection    [211373:Introduction:5, 184360:Mechanisms Of S...
# viral infections   [214924:The Interplay Between Covid-19 And Amp...
# viral replication  [214924:The Immune Response To Sars-Cov-2 ::: ...
# virus              [184360:Abstract:1, 211125:Discussion:25, 2113...
# vomiting           [179426:Glycemic Control ::: Special Aspects O...
#
#                                                                paper  \
# entity
# 4e-bp1                                                      [214924]
# ace                                         [214924, 179426, 184360]
# ace2               [184360, 211373, 211125, 214924, 160564, 17942...
# ace2 receptor                                       [214924, 211373]
# ace2 receptors                                      [211125, 214924]
# ...                                                              ...
# viral infection                             [214924, 184360, 211373]
# viral infections                                    [211125, 214924]
# viral replication                                           [214924]
# virus              [184360, 211373, 211125, 214924, 160564, 17942...
# vomiting                                                    [179426]
#
#                                                              section  \
# entity
# 4e-bp1             [214924:The Interplay Between Covid-19 And Amp...
# ace                [179426:Role Of Ace/Arbs , 214924:The Protecti...
# ace2               [214924:The Immune Response To Sars-Cov-2 , 19...
# ace2 receptor               [214924:Conclusion, 211373:Introduction]
# ace2 receptors     [214924:Angiotensin-Converting Enzyme 2 Expres...
# ...                                                              ...
# viral infection    [184360:Mechanisms Of Sars-Cov-2 Entry Into Ho...
# viral infections   [214924:The Interplay Between Covid-19 And Amp...
# viral replication  [214924:The Immune Response To Sars-Cov-2 , 21...
# virus              [214924:Abstract, 184360:Abstract, 214924:The ...
# vomiting           [179426:Glycemic Control , 179426:Measures For...
#
#                                                            raw_types  \
# entity
# 4e-bp1                                            [PROTEIN, PROTEIN]
# ace                [PROTEIN, PROTEIN, PROTEIN, PROTEIN, PROTEIN, ...
# ace2               [PROTEIN, PROTEIN, PROTEIN, PROTEIN, PROTEIN, ...
# ace2 receptor                                     [PROTEIN, PROTEIN]
# ace2 receptors                                    [PROTEIN, PROTEIN]
# ...                                                              ...
# viral infection    [PATHWAY, DISEASE, PATHWAY, DISEASE, PATHWAY, ...
# viral infections                         [DISEASE, DISEASE, DISEASE]
# viral replication                                 [PATHWAY, PATHWAY]
# virus              [ORGANISM, ORGANISM, ORGANISM, ORGANISM, ORGAN...
# vomiting                                          [DISEASE, DISEASE]
#
#                                                          uid  \
# entity
# 4e-bp1                                                   NaN
# ace                                                      NaN
# ace2                                                     NaN
# ace2 receptor                                            NaN
# ace2 receptors                                           NaN
# ...                                                      ...
# viral infection    http://purl.obolibrary.org/obo/NCIT_C3439
# viral infections                                         NaN
# viral replication                                        NaN
# virus                                                    NaN
# vomiting           http://purl.obolibrary.org/obo/NCIT_C3442
#
#                                                           definition  \
# entity
# 4e-bp1                                                           NaN
# ace                                                              NaN
# ace2                                                             NaN
# ace2 receptor                                                    NaN
# ace2 receptors                                                   NaN
# ...                                                              ...
# viral infection                       Any disease caused by a virus.
# viral infections                                                 NaN
# viral replication                                                NaN
# virus                                                            NaN
# vomiting           Forceful ejection of the contents of the stoma...
#
#                          semantic_type  \
# entity
# 4e-bp1                             NaN
# ace                                NaN
# ace2                               NaN
# ace2 receptor                      NaN
# ace2 receptors                     NaN
# ...                                ...
# viral infection    Disease or Syndrome
# viral infections                   NaN
# viral replication                  NaN
# virus                              NaN
# vomiting                       Finding
#
#                                                             taxonomy  \
# entity
# 4e-bp1                                                           NaN
# ace                                                              NaN
# ace2                                                             NaN
# ace2 receptor                                                    NaN
# ace2 receptors                                                   NaN
# ...                                                              ...
# viral infection    [('http://purl.obolibrary.org/obo/NCIT_C26726'...
# viral infections                                                 NaN
# viral replication                                                NaN
# virus                                                            NaN
# vomiting           [('http://purl.obolibrary.org/obo/NCIT_C3259',...
#
#                    paper_frequency entity_type entity_type_label
# entity
# 4e-bp1                           1     PROTEIN           PROTEIN
# ace                              3     PROTEIN           PROTEIN
# ace2                             7     PROTEIN           PROTEIN
# ace2 receptor                    2     PROTEIN           PROTEIN
# ace2 receptors                   2     PROTEIN           PROTEIN
# ...                            ...         ...               ...
# viral infection                  3     DISEASE           DISEASE
# viral infections                 2     DISEASE           DISEASE
# viral replication                1     PATHWAY           PATHWAY
# virus                            7    ORGANISM          ORGANISM
# vomiting                         1     DISEASE           DISEASE
#
# [261 rows x 12 columns]

# %%
curated_occurrence_data["paper"] = curated_occurrence_data["paper"].apply(lambda x: set(x))
curated_occurrence_data["paragraph"] = curated_occurrence_data["paragraph"].apply(lambda x: set(x))
curated_occurrence_data["section"] = curated_occurrence_data["section"].apply(lambda x: set(x))

# %%
curation_meta_data = {
    "factor_counts": factor_counts,
    "nodes_to_keep": curation_app.get_terms_to_include(),
    "n_most_frequent": curation_app.n_most_frequent if curation_app.n_most_frequent else 100
}

# %%
curation_meta_data
# Out:
# {'factor_counts': {'paper': 20, 'section': 108, 'paragraph': 286},
#  'nodes_to_keep': ['glucose'],
#  'n_most_frequent': 500}

# %%
# curated_occurrence_data.to_csv("data")
# with open("", "w") as f:
#     json.dumps(curation_meta_data, f)

# %%
# Glucose_risk_3000_paper_data.pkl
