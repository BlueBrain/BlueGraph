# %% [markdown]
# # Interactive curation of  entity occurrence data
#
# In this notebook we will illustrate how the curation application included in `cord_19` package can be used to perform interactive curation of named entity occurrence data.

# %%
import json
import zipfile

import pandas as pd

from cord_19.utils import (generate_curation_table,
                           link_ontology)
from cord_19.apps.curation_app import curation_app

# %% [markdown]
# ## Preparing entity occurrence data
#
# The input dataset contains occurrences of different terms in paragraphs of scientific articles from the CORD-19 dataset previously extracted by means of a Named Entity Recognition (NER) model.

# %%
data = pd.read_csv("../data/literature_NER_with_types.csv")

# %%
data
# Out:
#              entity entity_type         occurrence
# 0     Hyperglycemia     DISEASE      35198:Title:0
# 1         Prognosis     DISEASE      35198:Title:0
# 2          COVID-19     DISEASE      35198:Title:0
# 3          COVID-19     DISEASE      35198:Title:0
# 4       coronavirus    ORGANISM   35198:Abstract:1
# ...             ...         ...                ...
# 3521           ACE2     PROTEIN  214924:Caption:30
# 3522       COVID-19     DISEASE  214924:Caption:31
# 3523       Diabetes     DISEASE  214924:Caption:31
# 3524       Mellitus     DISEASE  214924:Caption:31
# 3525       COVID-19     DISEASE  214924:Caption:32
#
# [3526 rows x 3 columns]

# %%
print("Prepating curatation data...")
curation_input_table, factor_counts = generate_curation_table(data)
print("Done.")
# Out:
# Prepating curatation data...
# Cleaning up the entities...
# Aggregating occurrences of entities....
# Done.

# %%
curation_input_table
# Out:
#                 entity                                   raw_entity_types  \
# 0               4e-bp1                                 [PROTEIN, PROTEIN]
# 1                  ace  [PROTEIN, PROTEIN, PROTEIN, PROTEIN, PROTEIN, ...
# 2                ace-2  [PROTEIN, PROTEIN, PROTEIN, PROTEIN, PROTEIN, ...
# 3                 ace2  [PROTEIN, PROTEIN, PROTEIN, PROTEIN, PROTEIN, ...
# 4        ace2 receptor                                 [PROTEIN, PROTEIN]
# ..                 ...                                                ...
# 263  viral replication                                 [PATHWAY, PATHWAY]
# 264              virus  [ORGANISM, ORGANISM, ORGANISM, ORGANISM, ORGAN...
# 265        virus entry      [PATHWAY, PATHWAY, PATHWAY, PATHWAY, PATHWAY]
# 266            viruses  [ORGANISM, ORGANISM, ORGANISM, ORGANISM, ORGAN...
# 267           vomiting                                 [DISEASE, DISEASE]
#
#                                              paragraph  \
# 0    [214924:The Interplay Between Covid-19 And Amp...
# 1    [179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
# 2    [179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
# 3    [184360:Caption:70, 197804:Discussion:53, 2149...
# 4        [214924:Conclusion:28, 211373:Introduction:5]
# ..                                                 ...
# 263  [214924:The Immune Response To Sars-Cov-2 ::: ...
# 264  [179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
# 265  [184360:Anti-Dpp4 Vaccine ::: Therapeutic Pote...
# 266  [214924:The Immune Response To Sars-Cov-2 ::: ...
# 267  [179426:Glycemic Control ::: Special Aspects O...
#
#                                                  paper  \
# 0                                             [214924]
# 1                             [179426, 214924, 184360]
# 2                                             [179426]
# 3    [179426, 211373, 214924, 211125, 160564, 19780...
# 4                                     [214924, 211373]
# ..                                                 ...
# 263                                           [214924]
# 264           [179426, 214924, 211373, 197804, 184360]
# 265                                   [211373, 184360]
# 266                   [197804, 214924, 160564, 211125]
# 267                                           [179426]
#
#                                                section  paper_frequency  \
# 0    [214924:The Interplay Between Covid-19 And Amp...                1
# 1    [214924:Angiotensin-Converting Enzyme 2 Expres...                3
# 2    [179426:Role Of Antidiabetic Drugs In Current ...                1
# 3    [184360:Gliptins , 214924:Caption, 214924:Angi...                7
# 4             [211373:Introduction, 214924:Conclusion]                2
# ..                                                 ...              ...
# 263  [214924:The Protective Role Of Angiotensin-Con...                1
# 264  [184360:Gliptins , 214924:The Immune Response ...                5
# 265  [184360:Abstract, 184360:Anti-Dpp4 Vaccine , 2...                2
# 266  [197804:Introduction, 160564:Introduction, 214...                4
# 267  [179426:Measures For Good Health In Patients W...                1
#
#     entity_type
# 0       PROTEIN
# 1       PROTEIN
# 2       PROTEIN
# 3       PROTEIN
# 4       PROTEIN
# ..          ...
# 263     PATHWAY
# 264    ORGANISM
# 265     PATHWAY
# 266    ORGANISM
# 267     DISEASE
#
# [268 rows x 7 columns]

# %%
factor_counts
# Out:
# {'paper': 20, 'section': 108, 'paragraph': 286}

# %% [markdown]
# ## Loading NCIT ontology linking data

# %%
# Out:
# CPU times: user 2.39 s, sys: 289 ms, total: 2.68 s
# Wall time: 2.7 s

# %%
# %%time
print("Loading the ontology linking data...")
print("\tDecompressing the linking file...")
with zipfile.ZipFile("../data/NCIT_ontology_linking.csv.zip", 'r') as zip_ref:
    zip_ref.extractall("../data/")
    
print("\tLoading the linking dataframe in memory...")
ontology_linking = pd.read_csv("../data/NCIT_ontology_linking.csv")

print("\tLoading ontology type mapping...")
with open("../data/NCIT_type_mapping.json", "rb") as f:
    type_mapping = json.load(f)
print("Done.")
# Out:
# Loading the ontology linking data...
# 	Decompressing the linking file...
# 	Loading the linking dataframe in memory...
# 	Loading ontology type mapping...
# Done.
# CPU times: user 5.99 s, sys: 822 ms, total: 6.81 s
# Wall time: 6.86 s

# %%
ontology_linking
# Out:
#                                   mention  \
# 0                  endotracheal secretion
# 1                                immunity
# 2        mycoplasma pneumoniae infections
# 3                              infections
# 4                      community-acquired
# ...                                   ...
# 1015167                             cyp3a
# 1015168                              nadh
# 1015169                              copd
# 1015170                               cvd
# 1015171                              cvds
#
#                                        concept  \
# 0                                 endotracheal
# 1                                     immunity
# 2                        mycoplasma pneumoniae
# 3                          infectious disorder
# 4                 community-acquired pneumonia
# ...                                        ...
# 1015167                        cytochrome p450
# 1015168                                 nadide
# 1015169  chronic obstructive pulmonary disease
# 1015170                cardiovascular disorder
# 1015171                cardiovascular disorder
#
#                                                  uid  \
# 0         http://purl.obolibrary.org/obo/NCIT_C84984
# 1         http://purl.obolibrary.org/obo/NCIT_C16710
# 2         http://purl.obolibrary.org/obo/NCIT_C86599
# 3         http://purl.obolibrary.org/obo/NCIT_C26726
# 4        http://purl.obolibrary.org/obo/NCIT_C115163
# ...                                              ...
# 1015167   http://purl.obolibrary.org/obo/NCIT_C16484
# 1015168   http://purl.obolibrary.org/obo/NCIT_C87339
# 1015169    http://purl.obolibrary.org/obo/NCIT_C3199
# 1015170    http://purl.obolibrary.org/obo/NCIT_C2931
# 1015171    http://purl.obolibrary.org/obo/NCIT_C2931
#
#                                                 definition  \
# 0                                      Within the trachea.
# 1        The protection against infectious disease conf...
# 2        A species of anaerobic, Gram-negative, pseudo-...
# 3        A disorder resulting from the presence and act...
# 4        Pneumonia that is not acquired in a hospital o...
# ...                                                    ...
# 1015167  A family of cytochromes that are involved in e...
# 1015168  A dinucleotide of adenine and nicotinamide. It...
# 1015169  A chronic and progressive lung disorder charac...
# 1015170  A non-neoplastic or neoplastic disorder affect...
# 1015171  A non-neoplastic or neoplastic disorder affect...
#
#                            semantic_type  \
# 0                         Classification
# 1               Organ or Tissue Function
# 2                              Bacterium
# 3                    Disease or Syndrome
# 4                    Disease or Syndrome
# ...                                  ...
# 1015167  Amino Acid, Peptide, or Protein
# 1015168          Pharmacologic Substance
# 1015169              Disease or Syndrome
# 1015170              Disease or Syndrome
# 1015171              Disease or Syndrome
#
#                                                   taxonomy
# 0        [('http://purl.obolibrary.org/obo/NCIT_C13442'...
# 1        [('http://purl.obolibrary.org/obo/NCIT_C17937'...
# 2        [('http://purl.obolibrary.org/obo/NCIT_C73540'...
# 3        [('http://purl.obolibrary.org/obo/NCIT_C93210'...
# 4        [('http://purl.obolibrary.org/obo/NCIT_C3333',...
# ...                                                    ...
# 1015167  [('http://purl.obolibrary.org/obo/NCIT_C16486'...
# 1015168  [('http://purl.obolibrary.org/obo/NCIT_C1505',...
# 1015169  [('http://purl.obolibrary.org/obo/NCIT_C98541'...
# 1015170  [('http://purl.obolibrary.org/obo/NCIT_C27551'...
# 1015171  [('http://purl.obolibrary.org/obo/NCIT_C27551'...
#
# [1015172 rows x 6 columns]

# %%
type_mapping
# Out:
# {'DISEASE': {'include': ['Disease, Disorder or Finding']},
#  'Condition': {'include': ['Risk Factor',
#    'Personal Behavior',
#    'Industrial Waste',
#    'Health',
#    'Biospecimen Condition',
#    'Event',
#    'Care',
#    'Population Group Characteristic']},
#  'Biomarkers': {'include': ['Biomarker Analysis', 'Biomarker']},
#  'ORGANISM': {'include': ['Organism']},
#  'DRUG': {'include': ['Substance of Abuse',
#    'Dietary Supplement',
#    'Drug Class Measurement',
#    'Pharmacologic Substance']},
#  'CELL_COMPARTMENT': {'include': ['Cell Part']},
#  'PATHWAY': {'include': ['Biochemical Pathway', 'Biological Process']},
#  'CHEMICAL': {'include': ['Chemical Modifier',
#    'Drug or Chemical by Structure',
#    'Food or Food Product',
#    'Physiology-Regulatory Factor']},
#  'PROTEIN': {'include': ['Blood Protein Measurement',
#    'Protein or Riboprotein Complex',
#    'Protein or Enzyme Type Measurement',
#    'Protein',
#    'Hemoglobin Measurement',
#    'Gene Product',
#    'Vitamin Measurement',
#    'Cytokine Measurement']},
#  'CELL_TYPE': {'include': ['Abnormal Cell',
#    'Cell Count',
#    'Microanatomic Structure',
#    'Blood Cell Count']},
#  'ORGAN': {'include': ['Tissue',
#    'Organ',
#    'Body Region',
#    'Body Cavity',
#    'Organ System',
#    'Body Fluid or Substance'],
#   'exclude': ['Cell Part']},
#  'GENE': {'include': ['Gene']}}

# %% [markdown]
# ## Running the curation app

# %%
default_term_filters = ["glucose"]

# %%
curation_app.set_default_terms_to_include(default_term_filters)
curation_app.set_table(curation_input_table.copy())
curation_app.set_ontology_linking_callback(lambda x: link_ontology(ontology_linking, type_mapping, x))

# Try setting `mode="external"` to open the app in the new tab
curation_app.run(port=8070, mode="inline")
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8070/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Merging the occurrence data with the ontology linking...

# %% [markdown]
# ## Extracting curated data

# %%
curated_occurrence_data = curation_app.get_curated_table()

# %%
curated_occurrence_data
# Out:
#                                                                    aggregated_entities  \
# entity
# 4e-bp1                                                                        [4e-bp1]
# ace inhibitor                                     [acei, acei, acei, acei, acei, acei]
# acetaminophen                        [acetaminophen, acetaminophen, paracetamol, pa...
# acute lung injury                    [ali, ali, lung injury, lung injury, lung inju...
# acute respiratory distress syndrome  [acute respiratory distress syndrome, acute re...
# ...                                                                                ...
# viral                                                     [viral, viral, viral, viral]
# viral entry                                                              [viral entry]
# viral infection                      [viral infection, viral infection, viral infec...
# virus                                [virus, virus, virus, viruses, viruses, viruse...
# vomiting                                                          [vomiting, vomiting]
#
#                                                                       raw_entity_types  \
# entity
# 4e-bp1                                                              [PROTEIN, PROTEIN]
# ace inhibitor                        [PROTEIN, DRUG, DRUG, DRUG, DRUG, DRUG, PROTEI...
# acetaminophen                        [CHEMICAL, DRUG, CHEMICAL, DRUG, CHEMICAL, DRU...
# acute lung injury                    [DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, ...
# acute respiratory distress syndrome  [DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, ...
# ...                                                                                ...
# viral                                [ORGANISM, ORGANISM, ORGANISM, ORGANISM, ORGAN...
# viral entry                          [PATHWAY, PATHWAY, PATHWAY, PATHWAY, PATHWAY, ...
# viral infection                      [DISEASE, PATHWAY, DISEASE, DISEASE, DISEASE, ...
# virus                                [ORGANISM, ORGANISM, ORGANISM, ORGANISM, ORGAN...
# vomiting                                          [DISEASE, DISEASE, DISEASE, DISEASE]
#
#                                                                              paragraph  \
# entity
# 4e-bp1                               [214924:The Interplay Between Covid-19 And Amp...
# ace inhibitor                        [184360:Aceis And Arbs ::: Therapeutic Potenti...
# acetaminophen                        [197804:Discussion:52, 197804:Management Of Ch...
# acute lung injury                    [214924:The Protective Role Of Angiotensin-Con...
# acute respiratory distress syndrome  [184360:Pathophysiology Of Covid-19: Pulmonar ...
# ...                                                                                ...
# viral                                [179426:Association Of Diabetes With Acute Vir...
# viral entry                          [179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
# viral infection                      [184360:Mechanisms Of Sars-Cov-2 Entry Into Ho...
# virus                                [197804:Discussion:44, 184360:Sdpp4 As Soluble...
# vomiting                             [179426:Glycemic Control ::: Special Aspects O...
#
#                                                                                  paper  \
# entity
# 4e-bp1                                                                        [214924]
# ace inhibitor                                                         [197804, 184360]
# acetaminophen                                                         [179426, 197804]
# acute lung injury                                     [179426, 214924, 197804, 184360]
# acute respiratory distress syndrome   [179426, 129074, 214924, 211125, 197804, 184360]
# ...                                                                                ...
# viral                                         [179426, 211373, 214924, 211125, 184360]
# viral entry                                                           [179426, 214924]
# viral infection                                       [211373, 214924, 211125, 184360]
# virus                                [179426, 211373, 214924, 211125, 160564, 19780...
# vomiting                                                                      [179426]
#
#                                                                                section  \
# entity
# 4e-bp1                               [214924:The Interplay Between Covid-19 And Amp...
# ace inhibitor                        [197804:Management Of Children And Young Peopl...
# acetaminophen                        [197804:Management Of Children And Young Peopl...
# acute lung injury                    [184360:Ang-(1-7) Analogues , 184360:Aceis And...
# acute respiratory distress syndrome  [184360:Ang-(1-7) Analogues , 211125:Introduct...
# ...                                                                                ...
# viral                                [184360:Mechanisms Of Sars-Cov-2 Entry Into Ho...
# viral entry                          [179426:Conclusion, 214924:Angiotensin-Convert...
# viral infection                      [184360:Mechanisms Of Sars-Cov-2 Entry Into Ho...
# virus                                [184360:Gliptins , 197804:Introduction, 214924...
# vomiting                             [179426:Measures For Good Health In Patients W...
#
#                                                                              uid  \
# entity
# 4e-bp1                                                                       NaN
# ace inhibitor                           http://purl.obolibrary.org/obo/NCIT_C247
# acetaminophen                           http://purl.obolibrary.org/obo/NCIT_C198
# acute lung injury                    http://purl.obolibrary.org/obo/NCIT_C155766
# acute respiratory distress syndrome    http://purl.obolibrary.org/obo/NCIT_C3353
# ...                                                                          ...
# viral                                 http://purl.obolibrary.org/obo/NCIT_C27985
# viral entry                                                                  NaN
# viral infection                        http://purl.obolibrary.org/obo/NCIT_C3439
# virus                                 http://purl.obolibrary.org/obo/NCIT_C14283
# vomiting                               http://purl.obolibrary.org/obo/NCIT_C3442
#
#                                                                             definition  \
# entity
# 4e-bp1                                                                             NaN
# ace inhibitor                        Any substance that inhibits angiotensin-conver...
# acetaminophen                        A p-aminophenol derivative with analgesic and ...
# acute lung injury                    A finding of acute onset of bilateral pulmonar...
# acute respiratory distress syndrome  Progressive and life-threatening pulmonary dis...
# ...                                                                                ...
# viral                                                                              NaN
# viral entry                                                                        NaN
# viral infection                                         Any disease caused by a virus.
# virus                                An infectious agent which consists of two part...
# vomiting                             Forceful ejection of the contents of the stoma...
#
#                                                     semantic_type  \
# entity
# 4e-bp1                                                        NaN
# ace inhibitor                        Chemical Viewed Functionally
# acetaminophen                             Pharmacologic Substance
# acute lung injury                                         Finding
# acute respiratory distress syndrome           Disease or Syndrome
# ...                                                           ...
# viral                                         Qualitative Concept
# viral entry                                                   NaN
# viral infection                               Disease or Syndrome
# virus                                                       Virus
# vomiting                                                  Finding
#
#                                                                               taxonomy  \
# entity
# 4e-bp1                                                                             NaN
# ace inhibitor                        [('http://purl.obolibrary.org/obo/NCIT_C270', ...
# acetaminophen                        [('http://purl.obolibrary.org/obo/NCIT_C2356',...
# acute lung injury                    [('http://purl.obolibrary.org/obo/NCIT_C45233'...
# acute respiratory distress syndrome  [('http://purl.obolibrary.org/obo/NCIT_C28193'...
# ...                                                                                ...
# viral                                [('http://purl.obolibrary.org/obo/NCIT_C27993'...
# viral entry                                                                        NaN
# viral infection                      [('http://purl.obolibrary.org/obo/NCIT_C26726'...
# virus                                [('http://purl.obolibrary.org/obo/NCIT_C14250'...
# vomiting                             [('http://purl.obolibrary.org/obo/NCIT_C3259',...
#
#                                      paper_frequency entity_type  \
# entity
# 4e-bp1                                             1     PROTEIN
# ace inhibitor                                      2        DRUG
# acetaminophen                                      2        DRUG
# acute lung injury                                  4     DISEASE
# acute respiratory distress syndrome                6     DISEASE
# ...                                              ...         ...
# viral                                              5    ORGANISM
# viral entry                                        2     PATHWAY
# viral infection                                    4     DISEASE
# virus                                              7    ORGANISM
# vomiting                                           1     DISEASE
#
#                                     entity_type_label
# entity
# 4e-bp1                                        PROTEIN
# ace inhibitor                                    DRUG
# acetaminophen                                    DRUG
# acute lung injury                             DISEASE
# acute respiratory distress syndrome           DISEASE
# ...                                               ...
# viral                                        ORGANISM
# viral entry                                   PATHWAY
# viral infection                               DISEASE
# virus                                        ORGANISM
# vomiting                                      DISEASE
#
# [216 rows x 12 columns]

# %%
curated_occurrence_data["paper"] = curated_occurrence_data["paper"].apply(lambda x: set(x))
curated_occurrence_data["paragraph"] = curated_occurrence_data["paragraph"].apply(lambda x: set(x))
curated_occurrence_data["section"] = curated_occurrence_data["section"].apply(lambda x: set(x))

# %%
curation_meta_data = {
    "factor_counts": factor_counts,
    "nodes_to_keep": curation_app.get_terms_to_include(),
    "n_most_frequent": curation_app.n_most_frequent if curation_app.n_most_frequent else 100
}

# %%
curation_meta_data
# Out:
# {'factor_counts': {'paper': 20, 'section': 108, 'paragraph': 286},
#  'nodes_to_keep': ['glucose'],
#  'n_most_frequent': 500}

# %%
# curated_occurrence_data.to_csv("data")
# with open("", "w") as f:
#     json.dumps(curation_meta_data, f)
