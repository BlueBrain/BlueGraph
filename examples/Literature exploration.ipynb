# %% [markdown]
# # Literature exploration by term co-occurrance analysis
#
# In this example we illustrate how network analytics can be used for literature exploration.
#
# The input dataset contains occurrences of different terms in paragraphs of scientific articles previously extracted by means of a Named Entity Recognition (NER) model. This dataset is transformed into three co-occurrence networks: representing paper-, section- and paragraph-level co-occurrence relation between terms. The term relations in the above-mentioned networks are quantified using mutual-information-based scores (pointwise mutual information and its normalized version).
#
# The networks are further analysed using classical tools from complex networks: we find various centrality measures characterizing the importance of extracted terms, we detect term communities representing denesely connected clusters of terms and finally we illustrate how the algorithms for finding shortest paths and minimum spanning trees can be used to perform guided search in networks.

# %%
import networkx as nx
import pandas as pd
import numpy as np

# %%
from bluegraph.core import PandasPGFrame
from bluegraph.preprocess.generators import generate_cooccurrence_edges

from bluegraph.backends.graph_tool import GTMetricProcessor
from bluegraph.backends.networkx import NXMetricProcessor, NXPathFinder

# %% [markdown]
# ## Prepare entity-occurrence data property graph

# %% [markdown]
# The input data is given by occurrences of different entities in specific paragraphs of scientific articles.

# %%
mentions = pd.read_csv("data/literature_NER_example.csv")

# %% [markdown]
# Every paragraph is identified using the format `<paper_id>:<section_id>:<paragraph_id>`. From this data we will extract occurrences in distinct papers/sections/paragraphs as follows:

# %%
# Extract unique paper/seciton/paragraph identifiers
mentions["paper"] = mentions["occurrence"].apply(
    lambda x: x.split(":")[0])
mentions["section"] = mentions["occurrence"].apply(
    lambda x: ":".join([x.split(":")[0], x.split(":")[1]]))

mentions = mentions.rename(columns={"occurrence": "paragraph"})

# %% [markdown]
# We, first, create an empty property graph

# %%
graph = PandasPGFrame()

# %% [markdown]
# Then we add nodes for unique entities and papers

# %%
entity_nodes = mentions["entity"].unique()
graph.add_nodes(entity_nodes)
graph.add_node_types({n: "Entity" for n in entity_nodes})

paper_nodes = mentions["paper"].unique()
graph.add_nodes(paper_nodes)
graph.add_node_types({n: "Paper" for n in paper_nodes})

# %%
graph.nodes(raw_frame=True)
# Out:
#                                       @type
# @id
# ace inhibitor                        Entity
# acetaminophen                        Entity
# acute lung injury                    Entity
# acute respiratory distress syndrome  Entity
# adenosine                            Entity
# ...                                     ...
# 78884                                 Paper
# 35198                                 Paper
# 139943                                Paper
# 172581                                Paper
# 102473                                Paper
#
# [177 rows x 1 columns]

# %% [markdown]
# We now add edges from entities to the papers they occur in

# %%
occurrence_edges = mentions.groupby(by=["entity", "paper"]).aggregate(set)

# %%
occurrence_edges
# Out:
#                                                                   paragraph  \
# entity            paper
# ace inhibitor     184360  {184360:Caption:68, 184360:Conclusion:62, 1843...
#                   197804  {197804:Management Of Children And Young Peopl...
# acetaminophen     179426  {179426:Blood Glucose Monitoring ::: Special A...
#                   197804  {197804:Management Of Children And Young Peopl...
# acute lung injury 179426  {179426:Role Of Ace/Arbs ::: Special Aspects O...
# ...                                                                     ...
# virus             184360  {184360:Anti-Dpp4 Vaccine ::: Therapeutic Pote...
#                   197804      {197804:Discussion:44, 197804:Introduction:2}
#                   211125                             {211125:Discussion:25}
#                   211373  {211373:Introduction:3, 211373:Introduction:5,...
#                   214924  {214924:Abstract:1, 214924:Introduction:3, 214...
#
#                                                                     section
# entity            paper
# ace inhibitor     184360  {184360:Conclusion, 184360:Caption, 184360:Com...
#                   197804  {197804:Management Of Children And Young Peopl...
# acetaminophen     179426                 {179426:Blood Glucose Monitoring }
#                   197804  {197804:Management Of Children And Young Peopl...
# acute lung injury 179426                         {179426:Role Of Ace/Arbs }
# ...                                                                     ...
# virus             184360  {184360:Anti-Dpp4 Vaccine , 184360:Sdpp4 As So...
#                   197804           {197804:Discussion, 197804:Introduction}
#                   211125                                {211125:Discussion}
#                   211373                              {211373:Introduction}
#                   214924  {214924:Introduction, 214924:Abstract, 214924:...
#
# [551 rows x 2 columns]

# %%
graph.add_edges(occurrence_edges.index)
graph.add_edge_types({e: "OccursIn" for e in occurrence_edges.index})

# %%
occurrence_edges.index = occurrence_edges.index.rename(["@source_id", "@target_id"])

# %%
graph.add_edge_properties(occurrence_edges["paragraph"])
graph.add_edge_properties(occurrence_edges["section"])

# %%
graph.edges(raw_frame=True)
# Out:
#                                  @type  \
# @source_id        @target_id
# ace inhibitor     184360      OccursIn
#                   197804      OccursIn
# acetaminophen     179426      OccursIn
#                   197804      OccursIn
# acute lung injury 179426      OccursIn
# ...                                ...
# virus             184360      OccursIn
#                   197804      OccursIn
#                   211125      OccursIn
#                   211373      OccursIn
#                   214924      OccursIn
#
#                                                                       paragraph  \
# @source_id        @target_id
# ace inhibitor     184360      {184360:Caption:68, 184360:Conclusion:62, 1843...
#                   197804      {197804:Management Of Children And Young Peopl...
# acetaminophen     179426      {179426:Blood Glucose Monitoring ::: Special A...
#                   197804      {197804:Management Of Children And Young Peopl...
# acute lung injury 179426      {179426:Role Of Ace/Arbs ::: Special Aspects O...
# ...                                                                         ...
# virus             184360      {184360:Anti-Dpp4 Vaccine ::: Therapeutic Pote...
#                   197804          {197804:Discussion:44, 197804:Introduction:2}
#                   211125                                 {211125:Discussion:25}
#                   211373      {211373:Introduction:3, 211373:Introduction:5,...
#                   214924      {214924:Abstract:1, 214924:Introduction:3, 214...
#
#                                                                         section
# @source_id        @target_id
# ace inhibitor     184360      {184360:Conclusion, 184360:Caption, 184360:Com...
#                   197804      {197804:Management Of Children And Young Peopl...
# acetaminophen     179426                     {179426:Blood Glucose Monitoring }
#                   197804      {197804:Management Of Children And Young Peopl...
# acute lung injury 179426                             {179426:Role Of Ace/Arbs }
# ...                                                                         ...
# virus             184360      {184360:Anti-Dpp4 Vaccine , 184360:Sdpp4 As So...
#                   197804               {197804:Discussion, 197804:Introduction}
#                   211125                                    {211125:Discussion}
#                   211373                                  {211373:Introduction}
#                   214924      {214924:Introduction, 214924:Abstract, 214924:...
#
# [551 rows x 3 columns]

# %% [markdown]
# ## Generate co-occurrence networks

# %% [markdown]
# We will generate co-occurrence networks for difference occurrence factors (paper/section/paragraph), i.e. an edge between a pair of entities is added if they co-occur in the same paper/section/paragraph/

# %% [markdown]
# ### Paper-based co-occurrence

# %%
paper_cooccurrence_edges = generate_cooccurrence_edges(
    graph, "OccursIn", compute_statistics=["frequency", "ppmi", "npmi"])
# Out:
# Examining 12246 pairs of terms for co-occurrence...

# %%
paper_cooccurrence_edges["@type"] = "CoOccursWith"
paper_cooccurrence_edges
# Out:
#                                                                                common_factors  \
# @source_id      @target_id
# ace inhibitor   acetaminophen                                                        {197804}
#                 acute lung injury                                            {184360, 197804}
#                 acute respiratory distress syndrome                          {184360, 197804}
#                 adenosine                                                            {184360}
#                 adipose tissue                                               {184360, 197804}
# ...                                                                                       ...
# viral           viral infection                              {214924, 184360, 211125, 211373}
#                 virus                                {184360, 179426, 211373, 214924, 211125}
# viral entry     viral infection                                                      {214924}
#                 virus                                                        {214924, 179426}
# viral infection virus                                        {214924, 184360, 211125, 211373}
#
#                                                      frequency      ppmi  \
# @source_id      @target_id
# ace inhibitor   acetaminophen                                1  2.321928
#                 acute lung injury                            2  2.321928
#                 acute respiratory distress syndrome          2  1.736966
#                 adenosine                                    1  2.321928
#                 adipose tissue                               2  2.736966
# ...                                                        ...       ...
# viral           viral infection                              4  2.000000
#                 virus                                        5  1.514573
# viral entry     viral infection                              1  1.321928
#                 virus                                        2  1.514573
# viral infection virus                                        4  1.514573
#
#                                                          npmi         @type
# @source_id      @target_id
# ace inhibitor   acetaminophen                        0.537244  CoOccursWith
#                 acute lung injury                    0.698970  CoOccursWith
#                 acute respiratory distress syndrome  0.522879  CoOccursWith
#                 adenosine                            0.537244  CoOccursWith
#                 adipose tissue                       0.823909  CoOccursWith
# ...                                                       ...           ...
# viral           viral infection                      0.861353  CoOccursWith
#                 virus                                0.757287  CoOccursWith
# viral entry     viral infection                      0.305865  CoOccursWith
#                 virus                                0.455932  CoOccursWith
# viral infection virus                                0.652291  CoOccursWith
#
# [9748 rows x 5 columns]

# %%
entity_nodes = graph.nodes_of_type("Entity").copy()

# %%
paper_frequency = mentions.groupby("entity").aggregate(set)["paper"].apply(len)
paper_frequency.name = "paper_frequency"

section_frequency = mentions.groupby("entity").aggregate(set)["section"].apply(len)
section_frequency.name = "section_frequency"

paragraph_frequency = mentions.groupby("entity").aggregate(set)["paragraph"].apply(len)
paragraph_frequency.name = "paragraph_frequency"

entity_nodes["paper_frequency"] = paper_frequency
entity_nodes["section_frequency"] = section_frequency
entity_nodes["paragraph_frequency"] = paragraph_frequency

# %%
paper_network = PandasPGFrame.from_frames(
    nodes=entity_nodes,
    edges=paper_cooccurrence_edges,
    node_prop_types={
        "paper_frequency": "numeric",
        "section_frequency": "numeric",
        "paragraph_frequency": "numeric"
    },
    edge_prop_types={
        "frequency": "numeric",
        "ppmi": "numeric",
    })

# %%
paper_network.edges(raw_frame=True)
# Out:
#                                                                                common_factors  \
# @source_id      @target_id
# ace inhibitor   acetaminophen                                                        {197804}
#                 acute lung injury                                            {184360, 197804}
#                 acute respiratory distress syndrome                          {184360, 197804}
#                 adenosine                                                            {184360}
#                 adipose tissue                                               {184360, 197804}
# ...                                                                                       ...
# viral           viral infection                              {214924, 184360, 211125, 211373}
#                 virus                                {184360, 179426, 211373, 214924, 211125}
# viral entry     viral infection                                                      {214924}
#                 virus                                                        {214924, 179426}
# viral infection virus                                        {214924, 184360, 211125, 211373}
#
#                                                      frequency      ppmi  \
# @source_id      @target_id
# ace inhibitor   acetaminophen                                1  2.321928
#                 acute lung injury                            2  2.321928
#                 acute respiratory distress syndrome          2  1.736966
#                 adenosine                                    1  2.321928
#                 adipose tissue                               2  2.736966
# ...                                                        ...       ...
# viral           viral infection                              4  2.000000
#                 virus                                        5  1.514573
# viral entry     viral infection                              1  1.321928
#                 virus                                        2  1.514573
# viral infection virus                                        4  1.514573
#
#                                                          npmi         @type
# @source_id      @target_id
# ace inhibitor   acetaminophen                        0.537244  CoOccursWith
#                 acute lung injury                    0.698970  CoOccursWith
#                 acute respiratory distress syndrome  0.522879  CoOccursWith
#                 adenosine                            0.537244  CoOccursWith
#                 adipose tissue                       0.823909  CoOccursWith
# ...                                                       ...           ...
# viral           viral infection                      0.861353  CoOccursWith
#                 virus                                0.757287  CoOccursWith
# viral entry     viral infection                      0.305865  CoOccursWith
#                 virus                                0.455932  CoOccursWith
# viral infection virus                                0.652291  CoOccursWith
#
# [9748 rows x 5 columns]

# %%
paper_network.nodes(raw_frame=True)
# Out:
#                                       @type  paper_frequency  \
# @id
# ace inhibitor                        Entity                2
# acetaminophen                        Entity                2
# acute lung injury                    Entity                4
# acute respiratory distress syndrome  Entity                6
# adenosine                            Entity                2
# ...                                     ...              ...
# vildagliptin                         Entity                2
# viral                                Entity                5
# viral entry                          Entity                2
# viral infection                      Entity                4
# virus                                Entity                7
#
#                                      section_frequency  paragraph_frequency
# @id
# ace inhibitor                                        6                    9
# acetaminophen                                        3                    4
# acute lung injury                                   11                   12
# acute respiratory distress syndrome                 11                   17
# adenosine                                            2                    2
# ...                                                ...                  ...
# vildagliptin                                         2                    6
# viral                                               15                   21
# viral entry                                          5                    5
# viral infection                                      6                    6
# virus                                               18                   22
#
# [157 rows x 4 columns]

# %% [markdown]
# ### Section-based co-occurrence

# %%
def aggregate_sections(data):
    return set(sum(data["section"].apply(list), []))

# %%
section_cooccurrence_edges = generate_cooccurrence_edges(
    graph, "OccursIn", 
    factor_aggregator=aggregate_sections,
    compute_statistics=["frequency", "ppmi", "npmi"]
)
# Out:
# Examining 12246 pairs of terms for co-occurrence...

# %%
section_cooccurrence_edges["@type"] = "CoOccursWith"
section_cooccurrence_edges
# Out:
#                                                                                         common_factors  \
# @source_id      @target_id
# ace inhibitor   acetaminophen                        {197804:Management Of Children And Young Peopl...
#                 acute lung injury                             {184360:Caption, 184360:Aceis And Arbs }
#                 acute respiratory distress syndrome                                   {184360:Caption}
#                 angioedema                           {184360:Combined Therapeutic Potential Targeti...
#                 angiotensin ii receptor antagonist   {184360:Caption, 184360:Combined Therapeutic P...
# ...                                                                                                ...
# viral           viral entry                          {179426:Conclusion, 179426:Role Of Dpp4 Enzyme...
#                 viral infection                      {214924:The Immune Response To Sars-Cov-2 , 21...
#                 virus                                {214924:Abstract, 214924:The Immune Response T...
# viral entry     virus                                {179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
# viral infection virus                                {214924:The Protective Role Of Angiotensin-Con...
#
#                                                      frequency      ppmi  \
# @source_id      @target_id
# ace inhibitor   acetaminophen                                1  2.557995
#                 acute lung injury                            2  1.683526
#                 acute respiratory distress syndrome          1  0.683526
#                 angioedema                                   1  2.557995
#                 angiotensin ii receptor antagonist           3  3.405992
# ...                                                        ...       ...
# viral           viral entry                                  5  2.821030
#                 viral infection                              6  2.821030
#                 virus                                        9  1.821030
# viral entry     virus                                        2  1.236067
# viral infection virus                                        5  2.294961
#
#                                                          npmi         @type
# @source_id      @target_id
# ace inhibitor   acetaminophen                        0.380206  CoOccursWith
#                 acute lung injury                    0.293916  CoOccursWith
#                 acute respiratory distress syndrome  0.101595  CoOccursWith
#                 angioedema                           0.380206  CoOccursWith
#                 angiotensin ii receptor antagonist   0.662263  CoOccursWith
# ...                                                       ...           ...
# viral           viral entry                          0.640271  CoOccursWith
#                 viral infection                      0.680922  CoOccursWith
#                 virus                                0.511813  CoOccursWith
# viral entry     virus                                0.215797  CoOccursWith
# viral infection virus                                0.520873  CoOccursWith
#
# [5207 rows x 5 columns]

# %%
section_network = PandasPGFrame.from_frames(
    nodes=entity_nodes,
    edges=section_cooccurrence_edges,
    node_prop_types={
        "paper_frequency": "numeric",
        "section_frequency": "numeric",
        "paragraph_frequency": "numeric"
    },
    edge_prop_types={
        "frequency": "numeric",
        "ppmi": "numeric",
    })

# %% [markdown]
# ### Paragraph-based co-occurrence

# %%
def aggregate_paragraphs(data):
    return set(sum(data["paragraph"].apply(list), []))

# %%
paragraph_cooccurrence_edges = generate_cooccurrence_edges(
    graph, "OccursIn", 
    factor_aggregator=aggregate_paragraphs,
    compute_statistics=["frequency", "ppmi", "npmi"],
    parallelize=True, cores=8)
# Out:
# Examining 12246 pairs of terms for co-occurrence...

# %%
paragraph_cooccurrence_edges["@type"] = "CoOccursWith"
paragraph_cooccurrence_edges
# Out:
#                                                                       common_factors  \
# @source_id            @target_id
# acetaminophen         blood        {179426:Blood Glucose Monitoring ::: Special A...
#                       covid-19     {197804:Management Of Children And Young Peopl...
#                       glucose      {179426:Blood Glucose Monitoring ::: Special A...
#                       ibuprofen    {197804:Management Of Children And Young Peopl...
#                       insulin      {179426:Blood Glucose Monitoring ::: Special A...
# ...                                                                              ...
# tumor necrosis factor viral        {214924:The Protective Role Of Angiotensin-Con...
#                       virus        {214924:The Protective Role Of Angiotensin-Con...
# vildagliptin          viral        {179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
#                       viral entry  {179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
#                       virus        {179426:Role Of Dpp4 Enzyme And Dpp4 Inhibitor...
#
#                                    frequency      ppmi      npmi         @type
# @source_id            @target_id
# acetaminophen         blood                1  1.321928  0.162613  CoOccursWith
#                       covid-19             2  0.000000  0.000000  CoOccursWith
#                       glucose              1  0.669851  0.082400  CoOccursWith
#                       ibuprofen            2  5.129283  0.719467  CoOccursWith
#                       insulin              1  1.959358  0.241025  CoOccursWith
# ...                                      ...       ...       ...           ...
# tumor necrosis factor viral                2  2.415037  0.338749  CoOccursWith
#                       virus                1  1.347923  0.165811  CoOccursWith
# vildagliptin          viral                1  1.152003  0.141710  CoOccursWith
#                       viral entry          1  3.222392  0.396393  CoOccursWith
#                       virus                3  2.669851  0.407965  CoOccursWith
#
# [2755 rows x 5 columns]

# %%
paragraph_network = PandasPGFrame.from_frames(
    nodes=entity_nodes,
    edges=paragraph_cooccurrence_edges,
    node_prop_types={
        "paper_frequency": "numeric",
        "section_frequency": "numeric",
        "paragraph_frequency": "numeric"
    },
    edge_prop_types={
        "frequency": "numeric",
        "ppmi": "numeric",
    })

# %% [markdown]
# **NB**
#
# _Positive pointwise mutual information (PPMI)_ is defined as $PPMI(x, y) = \log_2{\frac{p(x, y)}{p(x)p(y)}} $, if $p(x) \neq 0$ and $p(y) \neq 0$, and $PPMI(x, y) = 0$ otherwise.
#
# _Normalized pointwise mutual information (NPMI)_ is defined as $NPMI(x, y) = \frac{PPMI(x, y)}{-\log_2{p(x, y)}} $.
#
# The mutual-information-based distances are caluculated as $\frac{1}{(N/P)PMI}$.

# %% [markdown]
# ### Create metric processor objects

# %%
import math

def compute_distance(x):
    return 1 / x if x > 0 else math.inf

# %%
npmi_distance = paper_network.edges(raw_frame=True)["npmi"].apply(compute_distance)
npmi_distance.name = "distance_npmi"
paper_network.add_edge_properties(npmi_distance, "numeric")

# %%
paper_network.edges(raw_frame=True)
# Out:
#                                                                                common_factors  \
# @source_id      @target_id
# ace inhibitor   acetaminophen                                                        {197804}
#                 acute lung injury                                            {184360, 197804}
#                 acute respiratory distress syndrome                          {184360, 197804}
#                 adenosine                                                            {184360}
#                 adipose tissue                                               {184360, 197804}
# ...                                                                                       ...
# viral           viral infection                              {214924, 184360, 211125, 211373}
#                 virus                                {184360, 179426, 211373, 214924, 211125}
# viral entry     viral infection                                                      {214924}
#                 virus                                                        {214924, 179426}
# viral infection virus                                        {214924, 184360, 211125, 211373}
#
#                                                      frequency      ppmi  \
# @source_id      @target_id
# ace inhibitor   acetaminophen                                1  2.321928
#                 acute lung injury                            2  2.321928
#                 acute respiratory distress syndrome          2  1.736966
#                 adenosine                                    1  2.321928
#                 adipose tissue                               2  2.736966
# ...                                                        ...       ...
# viral           viral infection                              4  2.000000
#                 virus                                        5  1.514573
# viral entry     viral infection                              1  1.321928
#                 virus                                        2  1.514573
# viral infection virus                                        4  1.514573
#
#                                                          npmi         @type  \
# @source_id      @target_id
# ace inhibitor   acetaminophen                        0.537244  CoOccursWith
#                 acute lung injury                    0.698970  CoOccursWith
#                 acute respiratory distress syndrome  0.522879  CoOccursWith
#                 adenosine                            0.537244  CoOccursWith
#                 adipose tissue                       0.823909  CoOccursWith
# ...                                                       ...           ...
# viral           viral infection                      0.861353  CoOccursWith
#                 virus                                0.757287  CoOccursWith
# viral entry     viral infection                      0.305865  CoOccursWith
#                 virus                                0.455932  CoOccursWith
# viral infection virus                                0.652291  CoOccursWith
#
#                                                      distance_npmi
# @source_id      @target_id
# ace inhibitor   acetaminophen                             1.861353
#                 acute lung injury                         1.430677
#                 acute respiratory distress syndrome       1.912489
#                 adenosine                                 1.861353
#                 adipose tissue                            1.213727
# ...                                                            ...
# viral           viral infection                           1.160964
#                 virus                                     1.320504
# viral entry     viral infection                           3.269412
#                 virus                                     2.193310
# viral infection virus                                     1.533058
#
# [9748 rows x 6 columns]

# %%
paper_metrics.graph.v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-3320c2a901e0> in <module>
# ----> 1 paper_metrics.graph.ep
#
# NameError: name 'paper_metrics' is not defined

# %%
paper_metrics.graph.ep["distance_npmi"][e]
# Out:
# 1.8613531161467862

# %%
npmi_distance = section_network.edges(raw_frame=True)["npmi"].apply(compute_distance)
npmi_distance.name = "distance_npmi"
section_network.add_edge_properties(npmi_distance, "numeric")

# %%
npmi_distance = paragraph_network.edges(raw_frame=True)["npmi"].apply(compute_distance)
npmi_distance.name = "distance_npmi"
paragraph_network.add_edge_properties(npmi_distance, "numeric")

# %% [markdown]
# Density of a network is quantified by the proportion of all possible edges ($n(n-1) / 2$ for the undirected network with $n$ nodes) that are realized.

# %%
paper_metrics = GTMetricProcessor(paper_network)
section_metrics = GTMetricProcessor(section_network)
paragraph_metrics = GTMetricProcessor(paragraph_network)

# %%
paper_metrics.graph.ep
# Out:
# {'common_factors': <EdgePropertyMap object with value type 'string', for Graph 0x7fd48ea853c8, at 0x7fd48ed3de80>, 'frequency': <EdgePropertyMap object with value type 'double', for Graph 0x7fd48ea853c8, at 0x7fd48e096438>, 'ppmi': <EdgePropertyMap object with value type 'double', for Graph 0x7fd48ea853c8, at 0x7fd48e096a58>, 'npmi': <EdgePropertyMap object with value type 'string', for Graph 0x7fd48ea853c8, at 0x7fd48e0964a8>, '@type': <EdgePropertyMap object with value type 'string', for Graph 0x7fd48ea853c8, at 0x7fd48e096b38>, 'distance_npmi': <EdgePropertyMap object with value type 'string', for Graph 0x7fd48ea853c8, at 0x7fd48e096d68>}

# %%
print("Density of the paper-based network: ", paper_metrics.density())
print("Density of the section-based network: ", section_metrics.density())
print("Density of the paragraph-based network: ", paragraph_metrics.density())
# Out:
# Density of the paper-based network:  0.7960150253143884
# Density of the section-based network:  0.42520006532745386
# Density of the paragraph-based network:  0.22497141923893516

# %% [markdown]
# The results above show that in the paper, section and paragraph network repsectively 80%, 42% and 22% of all possible term pairs co-occur at least once.

# %% [markdown]
# ## Nearest neighours by (N/P)MI

# %% [markdown]
# To illustrate the importance of computing mutual-information-based scores over raw frequencies consider the following example, where we would like to estimate top closest (most related) neighbors to a specific term.
#
# We will use the paragraph-based network and the raw co-occurrence frequency as the weight of our co-occurrence relation.

# %%
paragraph_path_finder = NXPathFinder(paragraph_network)

# %%
paragraph_path_finder.top_neighbors("glucose", 10, weight="frequency")
# Out:
# {'covid-19': 29,
#  'diabetes mellitus': 29,
#  'blood': 18,
#  'insulin': 11,
#  'death': 9,
#  'coronavirus': 8,
#  'hyperglycemia': 8,
#  'infectious disorder': 6,
#  'inflammation': 6,
#  'sars coronavirus': 6}

# %%
paragraph_path_finder.top_neighbors("lung", 10, weight="frequency")
# Out:
# {'covid-19': 24,
#  'angiotensin-converting enzyme 2': 16,
#  'sars-cov-2': 13,
#  'acute lung injury': 12,
#  'diabetes mellitus': 10,
#  'pulmonary': 10,
#  'sars coronavirus': 10,
#  'human': 9,
#  'viral': 9,
#  'mouse': 7}

# %% [markdown]
# We observe that 'glucose' and 'lung' share a lot of the closest neighbors by raw frequency. If we look into the list of top 10 entities by paragraph frequency in the entire corpus and we notice that 'glucose' and 'blood' co-occur the most with the terms that are simply the most frequent in our corpus, such as 'covid-19' and 'diabetes mellitus'.
#
# (Closest inspection of the distribution of weighted node degrees suggests that the network contains _hubs_, nodes with significantly high-degree connectivity to other nodes.)

# %%
paragraph_network.nodes(raw_frame=True).nlargest(10, columns=["paragraph_frequency"])
# Out:
#                                   @type  paper_frequency  section_frequency  \
# @id
# covid-19                         Entity               20                 94
# diabetes mellitus                Entity               19                 82
# sars-cov-2                       Entity                7                 36
# glucose                          Entity               13                 31
# angiotensin-converting enzyme 2  Entity                7                 26
# dipeptidyl peptidase 4           Entity                4                 17
# coronavirus                      Entity               16                 27
# blood                            Entity                8                 21
# lung                             Entity                6                 18
# sars coronavirus                 Entity                8                 18
#
#                                  paragraph_frequency
# @id
# covid-19                                         192
# diabetes mellitus                                156
# sars-cov-2                                        63
# glucose                                           44
# angiotensin-converting enzyme 2                   41
# dipeptidyl peptidase 4                            41
# coronavirus                                       31
# blood                                             28
# lung                                              28
# sars coronavirus                                  26

# %% [markdown]
# To account for the presence of such hubs, we use the mutual-information-based scores presented above. They 'balance' the influence of the highly connected hub nodes such as 'covid-19' and 'diabetes mellitus' in our example.

# %%
paragraph_path_finder.top_neighbors("glucose", 10, weight="npmi")
# Out:
# {'blood': 0.5133209650995287,
#  'glucose metabolism disorder': 0.43558951200762297,
#  'insulin': 0.41957609533629175,
#  'thrombophilia': 0.4079646453270325,
#  'bals r': 0.3744908698338857,
#  'insulin infusion': 0.3744908698338857,
#  'leukopenia': 0.3744908698338857,
#  'millimole per liter': 0.3744908698338857,
#  'troponin t, cardiac muscle': 0.3744908698338857,
#  'hyperglycemia': 0.3255525953220345}

# %%
paragraph_path_finder.top_neighbors("lung", 10, weight="npmi")
# Out:
# {'acute lung injury': 0.731006557092012,
#  'pulmonary': 0.6362945400636919,
#  'angiotensin-converting enzyme 2': 0.4757184436640079,
#  'receptor binding': 0.46595542454855043,
#  'animal': 0.4465392749200213,
#  'viral infection': 0.4465392749200213,
#  'mouse': 0.4362945258726772,
#  'angiotensin-1': 0.4259996541516483,
#  'viral': 0.4233482775367079,
#  'human': 0.4098154380746763}

# %% [markdown]
# ## Node centralities
#
# In this example we will compute the Degree and PageRank centralities only for the raw frequency, and the Betweenness centrality for the mutual-information-based scores.

# %% [markdown]
# _Degree centrality_ is given by the sum of weights of all incident edges of the given node and characterizes the importance of the node in the network in terms of its connectivity to other nodes (high degree = high connectivity).

# %%
paragraph_metrics.degree_centrality("frequency", write=True, write_property="degree")

# %% [markdown]
# _PageRank centrality_ is another measure that estimated the importance of the given node in the network. Roughly speaking it can be interpreted as the probablity that having landed on a random node in the network we will jump to the given node (here the edge weights are taken into account").
#
# https://en.wikipedia.org/wiki/PageRank

# %%
paragraph_metrics.pagerank_centrality("frequency", write=True, write_property="pagerank")

# %% [markdown]
# We then compute the betweenness centrality based on the NPMI distances.
#
# _Betweenness centrality_ is a node importance measure that estimates how often a shortest path between a pair of nodes will pass through the given node.

# %%
paragraph_metrics.betweenness_centrality("distance_npmi", write=True, write_property="betweenness")

# %%
new_paragraph_graph = paragraph_metrics.get_pgframe()

# %%
new_paragraph_graph.nodes(raw_frame=True)
# Out:
#                                       @type  paper_frequency  \
# @id
# ace inhibitor                        Entity              2.0
# acetaminophen                        Entity              2.0
# acute lung injury                    Entity              4.0
# acute respiratory distress syndrome  Entity              6.0
# adenosine                            Entity              2.0
# ...                                     ...              ...
# vildagliptin                         Entity              2.0
# viral                                Entity              5.0
# viral entry                          Entity              2.0
# viral infection                      Entity              4.0
# virus                                Entity              7.0
#
#                                      section_frequency  paragraph_frequency  \
# @id
# ace inhibitor                                      6.0                  9.0
# acetaminophen                                      3.0                  4.0
# acute lung injury                                 11.0                 12.0
# acute respiratory distress syndrome               11.0                 17.0
# adenosine                                          2.0                  2.0
# ...                                                ...                  ...
# vildagliptin                                       2.0                  6.0
# viral                                             15.0                 21.0
# viral entry                                        5.0                  5.0
# viral infection                                    6.0                  6.0
# virus                                             18.0                 22.0
#
#                                      degree  pagerank  betweenness
# @id
# ace inhibitor                          47.0  0.004152     0.000207
# acetaminophen                           7.0  0.001491     0.000000
# acute lung injury                     133.0  0.009832     0.015261
# acute respiratory distress syndrome   153.0  0.011580     0.014640
# adenosine                              24.0  0.002613     0.009377
# ...                                     ...       ...          ...
# vildagliptin                           59.0  0.005170     0.003060
# viral                                 227.0  0.016691     0.012242
# viral entry                            58.0  0.004936     0.015509
# viral infection                        60.0  0.004988     0.006286
# virus                                 214.0  0.015547     0.005790
#
# [157 rows x 7 columns]

# %%
print("Top 10 nodes by degree")
for n in new_paragraph_graph.nodes(raw_frame=True).nlargest(10, columns=["degree"]).index:
    print("\t", n)
# Out:
# Top 10 nodes by degree
# 	 covid-19
# 	 diabetes mellitus
# 	 sars-cov-2
# 	 angiotensin-converting enzyme 2
# 	 dipeptidyl peptidase 4
# 	 lung
# 	 glucose
# 	 coronavirus
# 	 sars coronavirus
# 	 viral

# %%
print("Top 10 nodes by PageRank")
for n in new_paragraph_graph.nodes(raw_frame=True).nlargest(10, columns=["pagerank"]).index:
    print("\t", n)
# Out:
# Top 10 nodes by PageRank
# 	 covid-19
# 	 diabetes mellitus
# 	 sars-cov-2
# 	 angiotensin-converting enzyme 2
# 	 dipeptidyl peptidase 4
# 	 glucose
# 	 lung
# 	 coronavirus
# 	 viral
# 	 sars coronavirus

# %%
print("Top 10 nodes by betweenness")
for n in new_paragraph_graph.nodes(raw_frame=True).nlargest(10, columns=["betweenness"]).index:
    print("\t", n)
# Out:
# Top 10 nodes by betweenness
# 	 lymphopenia
# 	 pulmonary
# 	 glucose metabolism disorder
# 	 t-lymphocyte
# 	 cough
# 	 chemokine
# 	 d-dimer measurement
# 	 kidney
# 	 interleukin-19
# 	 ibuprofen

# %% [markdown]
# ## Compute multiple metrics in one go

# %% [markdown]
# Alternatively, we can compute all the metrics in one go. To do so, we need to specify edge attributes used for computing different metrics (if an empty list is specified as a weight list for a metric, computation of this metric is not performed).
#
# We select the paragraph-based network and re-compute all some of the previously illustrated metrics as follows:

# %%
result_metrics = paragraph_metrics.compute_all_node_metrics(
    degree_weights=["frequency"],
    pagerank_weights=["frequency"],
    betweenness_weights=["distance_npmi"])

# %%
result_metrics
# Out:
# {'degree': {'frequency': {'ace inhibitor': 47.0,
#    'acetaminophen': 7.0,
#    'acute lung injury': 133.0,
#    'acute respiratory distress syndrome': 153.0,
#    'adenosine': 24.0,
#    'adipose tissue': 28.0,
#    'angioedema': 23.0,
#    'angiotensin ii receptor antagonist': 87.0,
#    'angiotensin-1': 77.0,
#    'angiotensin-2': 19.0,
#    'angiotensin-converting enzyme': 13.0,
#    'angiotensin-converting enzyme 2': 366.0,
#    'animal': 53.0,
#    'apoptosis': 20.0,
#    'bals r': 6.0,
#    'basal': 36.0,
#    'blood': 174.0,
#    'blood vessel': 30.0,
#    'bradykinin': 18.0,
#    'c-c motif chemokine 1': 48.0,
#    'c-reactive protein': 35.0,
#    'cardiac failure': 18.0,
#    'cardiovascular disorder': 109.0,
#    'cardiovascular system': 119.0,
#    'cd44 antigen': 46.0,
#    'cellular secretion': 49.0,
#    'cerebrovascular': 19.0,
#    'chemokine': 45.0,
#    'chest pain': 23.0,
#    'chloroquine': 8.0,
#    'chronic disease': 12.0,
#    'chronic kidney disease': 19.0,
#    'comorbidity': 19.0,
#    'confounding factors': 26.0,
#    'coronaviridae': 65.0,
#    'coronavirus': 247.0,
#    'cough': 53.0,
#    'covid-19': 967.0,
#    'cytokine': 153.0,
#    'd-dimer measurement': 91.0,
#    'death': 201.0,
#    'degradation': 24.0,
#    'diabetes mellitus': 740.0,
#    'diabetic ketoacidosis': 50.0,
#    'diarrhea, ctcae': 38.0,
#    'dipeptidyl peptidase 4': 280.0,
#    'dna replication': 69.0,
#    'dpp4i': 110.0,
#    'dyspnea': 23.0,
#    'extracellular matrix': 14.0,
#    'fatigue': 23.0,
#    'fever': 41.0,
#    'glucose': 277.0,
#    'glucose metabolism disorder': 56.0,
#    'glyburide': 181.0,
#    'glycosylated hemoglobin measurement': 27.0,
#    'growth factor': 22.0,
#    'h1n1': 18.0,
#    'hcp': 25.0,
#    'headache': 25.0,
#    'heart': 114.0,
#    'heart failure': 18.0,
#    'high sensitivity c-reactive protein measurement': 55.0,
#    'hiv entry inhibitor': 61.0,
#    'hmg-coa reductase inhibitor': 20.0,
#    'host cell': 60.0,
#    'human': 195.0,
#    'human dpp4': 23.0,
#    'human immunodeficiency virus': 41.0,
#    'human kidney organoids': 18.0,
#    'humoral immunity': 20.0,
#    'hyperglycemia': 115.0,
#    'hypertension': 168.0,
#    'hypoxia': 16.0,
#    'ibuprofen': 24.0,
#    'immune cell': 28.0,
#    'immune response process': 36.0,
#    'infectious disorder': 203.0,
#    'inflammation': 172.0,
#    'influenza': 28.0,
#    'insulin': 120.0,
#    'insulin infusion': 14.0,
#    'insulin resistance': 71.0,
#    'interleukin': 20.0,
#    'interleukin 1 beta measurement': 81.0,
#    'interleukin-19': 60.0,
#    'interleukin-6': 216.0,
#    'interleukin-8': 38.0,
#    'islet of langerhans': 19.0,
#    'iv': 5.0,
#    'janus bifrons': 4.0,
#    'kidney': 90.0,
#    'leucopenia': 20.0,
#    'leukopenia': 26.0,
#    'liver': 44.0,
#    'lower respiratory tract infection': 44.0,
#    'lung': 279.0,
#    'lymphocyte': 55.0,
#    'lymphopenia': 55.0,
#    'm protein': 11.0,
#    'macrophage': 44.0,
#    'mellitus': 3.0,
#    'metformin': 41.0,
#    'middle east respiratory syndrome': 67.0,
#    'middle east respiratory syndrome coronavirus': 188.0,
#    'millimole per liter': 16.0,
#    'molecule': 20.0,
#    'mouse': 149.0,
#    'multi-organ dysfunction': 24.0,
#    'muscle': 15.0,
#    'myalgia': 10.0,
#    'myocardium': 18.0,
#    'neoplasm': 28.0,
#    'nephropathy': 14.0,
#    'neutrophil': 66.0,
#    'obesity': 101.0,
#    'oral cavity': 64.0,
#    'organ': 26.0,
#    'oxygen': 14.0,
#    'person': 48.0,
#    'plasma': 59.0,
#    'plasmid': 23.0,
#    'pneumonia': 131.0,
#    'prognosis': 4.0,
#    'proliferation': 84.0,
#    'pulmonary': 142.0,
#    'rbd': 21.0,
#    'receptor binding': 13.0,
#    'renal': 40.0,
#    'respiratory failure': 23.0,
#    'respiratory system': 43.0,
#    'sars coronavirus': 227.0,
#    'sars-cov-2': 462.0,
#    'saxagliptin': 52.0,
#    'septicemia': 7.0,
#    'serum': 29.0,
#    'serum ferritin': 59.0,
#    'severe acute respiratory syndrome': 30.0,
#    'shortness of breath visual analogue scale': 22.0,
#    'sitagliptin': 118.0,
#    'sulfonylurea antidiabetic agent': 29.0,
#    'survival': 40.0,
#    't-lymphocyte': 60.0,
#    'therapeutic corticosteroid': 30.0,
#    'thrombophilia': 39.0,
#    'tissue': 34.0,
#    'transmembrane protein': 23.0,
#    'troponin t, cardiac muscle': 26.0,
#    'tumor necrosis factor': 60.0,
#    'tzd': 26.0,
#    'vaccine': 36.0,
#    'vascular': 130.0,
#    'vildagliptin': 59.0,
#    'viral': 227.0,
#    'viral entry': 58.0,
#    'viral infection': 60.0,
#    'virus': 214.0}},
#  'pagerank': {'frequency': {'ace inhibitor': 0.004152458029344015,
#    'acetaminophen': 0.0014906961813661434,
#    'acute lung injury': 0.009832243982126678,
#    'acute respiratory distress syndrome': 0.011580030547361387,
#    'adenosine': 0.002612937014598164,
#    'adipose tissue': 0.0028758451874745508,
#    'angioedema': 0.002725347645783217,
#    'angiotensin ii receptor antagonist': 0.006901545362098664,
#    'angiotensin-1': 0.0060586797066069075,
#    'angiotensin-2': 0.002338880893244231,
#    'angiotensin-converting enzyme': 0.002011635050939988,
#    'angiotensin-converting enzyme 2': 0.026326895480669122,
#    'animal': 0.0045231222225027064,
#    'apoptosis': 0.0023214366343953133,
#    'bals r': 0.0013340881849877326,
#    'basal': 0.003304187290243935,
#    'blood': 0.013341979661426105,
#    'blood vessel': 0.0030240632954701037,
#    'bradykinin': 0.002581664275366596,
#    'c-c motif chemokine 1': 0.004185294268831437,
#    'c-reactive protein': 0.003424691967290455,
#    'cardiac failure': 0.0022556609336875453,
#    'cardiovascular disorder': 0.008508007460430825,
#    'cardiovascular system': 0.009221594415812398,
#    'cd44 antigen': 0.004143074764868434,
#    'cellular secretion': 0.004419504769772333,
#    'cerebrovascular': 0.002246677889687307,
#    'chemokine': 0.004380628762362812,
#    'chest pain': 0.0027802857337129957,
#    'chloroquine': 0.0017147994271386232,
#    'chronic disease': 0.0017287242160751721,
#    'chronic kidney disease': 0.00230381370076683,
#    'comorbidity': 0.002158974154553018,
#    'confounding factors': 0.002801958407916368,
#    'coronaviridae': 0.005317891745565911,
#    'coronavirus': 0.01799883462743997,
#    'cough': 0.005159150851187762,
#    'covid-19': 0.06886925957123359,
#    'cytokine': 0.011523563418163421,
#    'd-dimer measurement': 0.007463840079219117,
#    'death': 0.014754648565919582,
#    'degradation': 0.003134396874894728,
#    'diabetes mellitus': 0.05261167520597816,
#    'diabetic ketoacidosis': 0.0043813521203349085,
#    'diarrhea, ctcae': 0.004182703039411019,
#    'dipeptidyl peptidase 4': 0.021188107027129966,
#    'dna replication': 0.00567381510604976,
#    'dpp4i': 0.008712656447381872,
#    'dyspnea': 0.0028790065009840736,
#    'extracellular matrix': 0.002191876245933133,
#    'fatigue': 0.0028790065009840736,
#    'fever': 0.004272038839579367,
#    'glucose': 0.020734003596608562,
#    'glucose metabolism disorder': 0.004914700809530222,
#    'glyburide': 0.013783247306899648,
#    'glycosylated hemoglobin measurement': 0.00290414740509276,
#    'growth factor': 0.002469690035258013,
#    'h1n1': 0.002250549567658149,
#    'hcp': 0.0025663414235044726,
#    'headache': 0.003159527850599882,
#    'heart': 0.009007303506906924,
#    'heart failure': 0.0022556609336875457,
#    'high sensitivity c-reactive protein measurement': 0.0048493330535681525,
#    'hiv entry inhibitor': 0.0049761828907330455,
#    'hmg-coa reductase inhibitor': 0.0022602018822671377,
#    'host cell': 0.0049064465033281345,
#    'human': 0.014265073738463651,
#    'human dpp4': 0.0024371104116018344,
#    'human immunodeficiency virus': 0.0035919497278639233,
#    'human kidney organoids': 0.0021348586982227248,
#    'humoral immunity': 0.002349206494761052,
#    'hyperglycemia': 0.009208086694322614,
#    'hypertension': 0.012718127893611025,
#    'hypoxia': 0.0020668076933929207,
#    'ibuprofen': 0.0030630942066669983,
#    'immune cell': 0.003305380772809256,
#    'immune response process': 0.0033980167402726364,
#    'infectious disorder': 0.014885039899702902,
#    'inflammation': 0.012935117049216512,
#    'influenza': 0.0029161581949291708,
#    'insulin': 0.009661985638993136,
#    'insulin infusion': 0.0018719164969189885,
#    'insulin resistance': 0.005804883687854388,
#    'interleukin': 0.0023600573383962477,
#    'interleukin 1 beta measurement': 0.006619614559427507,
#    'interleukin-19': 0.005172355295687237,
#    'interleukin-6': 0.0160318203708865,
#    'interleukin-8': 0.003678320997953137,
#    'islet of langerhans': 0.002163810168057412,
#    'iv': 0.0013073526599321629,
#    'janus bifrons': 0.001206524346893674,
#    'kidney': 0.007373366095259822,
#    'leucopenia': 0.0026437243564841435,
#    'leukopenia': 0.0027398831733284595,
#    'liver': 0.0041205937685508415,
#    'lower respiratory tract infection': 0.004215253952500799,
#    'lung': 0.01987603246408639,
#    'lymphocyte': 0.004743480432576459,
#    'lymphopenia': 0.004984120916010568,
#    'm protein': 0.001768282426683341,
#    'macrophage': 0.003971825629655109,
#    'mellitus': 0.0011368152454454548,
#    'metformin': 0.003814744177910735,
#    'middle east respiratory syndrome': 0.005471118248902777,
#    'middle east respiratory syndrome coronavirus': 0.013542484986260182,
#    'millimole per liter': 0.002012114886348464,
#    'molecule': 0.0026394691991344626,
#    'mouse': 0.011038161664515397,
#    'multi-organ dysfunction': 0.0028074755065375036,
#    'muscle': 0.00210135420719905,
#    'myalgia': 0.0019203030930301014,
#    'myocardium': 0.0021616276094056563,
#    'neoplasm': 0.0029233275254040778,
#    'nephropathy': 0.0019913869279294958,
#    'neutrophil': 0.005492199855460827,
#    'obesity': 0.008069188655730612,
#    'oral cavity': 0.005438298759510575,
#    'organ': 0.002878024503339599,
#    'oxygen': 0.001976732147019142,
#    'person': 0.004154181126187047,
#    'plasma': 0.00496560591965284,
#    'plasmid': 0.0026700065358654683,
#    'pneumonia': 0.010452913508179843,
#    'prognosis': 0.0012126066748934063,
#    'proliferation': 0.006756467796314194,
#    'pulmonary': 0.01081993223187879,
#    'rbd': 0.002411895527887984,
#    'receptor binding': 0.0018097928573061603,
#    'renal': 0.0038370566828956434,
#    'respiratory failure': 0.0027899020739369255,
#    'respiratory system': 0.004197271541140391,
#    'sars coronavirus': 0.016399971886118914,
#    'sars-cov-2': 0.0332825611501555,
#    'saxagliptin': 0.004512206446156022,
#    'septicemia': 0.0014209024553975959,
#    'serum': 0.002895491900256021,
#    'serum ferritin': 0.005118237763288477,
#    'severe acute respiratory syndrome': 0.0028550838106643564,
#    'shortness of breath visual analogue scale': 0.0026612553474513623,
#    'sitagliptin': 0.009763944249960342,
#    'sulfonylurea antidiabetic agent': 0.0029641877090782203,
#    'survival': 0.0036468377717435454,
#    't-lymphocyte': 0.005552101612082121,
#    'therapeutic corticosteroid': 0.00304666704540994,
#    'thrombophilia': 0.003695323394049084,
#    'tissue': 0.00339631656457414,
#    'transmembrane protein': 0.002601807301922339,
#    'troponin t, cardiac muscle': 0.00273988317332846,
#    'tumor necrosis factor': 0.005237024505323946,
#    'tzd': 0.0028019584079163684,
#    'vaccine': 0.0033737875831698553,
#    'vascular': 0.009777903022422508,
#    'vildagliptin': 0.0051695753974040845,
#    'viral': 0.01669077355352824,
#    'viral entry': 0.004936393184985871,
#    'viral infection': 0.004988105635258172,
#    'virus': 0.01554741940921319}},
#  'betweenness': {'frequency': {'ace inhibitor': 0.0031726969815071182,
#    'acetaminophen': 2.911716571114809e-05,
#    'acute lung injury': 0.004470351430982049,
#    'acute respiratory distress syndrome': 0.02347892675163299,
#    'adenosine': 0.001995979805287284,
#    'adipose tissue': 0.004858538035566121,
#    'angioedema': 0.0018856730025380286,
#    'angiotensin ii receptor antagonist': 0.0061323482124276555,
#    'angiotensin-1': 0.004847032484372442,
#    'angiotensin-2': 0.00366233858923152,
#    'angiotensin-converting enzyme': 0.0011881697803758668,
#    'angiotensin-converting enzyme 2': 0.021627821809605072,
#    'animal': 0.004601342421046841,
#    'apoptosis': 0.0022205037553898665,
#    'bals r': 0.0,
#    'basal': 0.0007289315916460038,
#    'blood': 0.030273047764848657,
#    'blood vessel': 0.0015060226600319274,
#    'bradykinin': 0.0008015523216948541,
#    'c-c motif chemokine 1': 0.0034960030637489863,
#    'c-reactive protein': 0.0032863614052196957,
#    'cardiac failure': 0.001129756362501045,
#    'cardiovascular disorder': 0.008974358906862507,
#    'cardiovascular system': 0.012650890023013237,
#    'cd44 antigen': 0.002994707213200598,
#    'cellular secretion': 0.004872850070648193,
#    'cerebrovascular': 0.0008609405145247973,
#    'chemokine': 0.01172184632808308,
#    'chest pain': 0.003338414962879615,
#    'chloroquine': 0.0004229692271646813,
#    'chronic disease': 0.0003943094517654381,
#    'chronic kidney disease': 0.003764954664957872,
#    'comorbidity': 0.00015112259001500295,
#    'confounding factors': 0.0014853923510159434,
#    'coronaviridae': 0.004026043917797912,
#    'coronavirus': 0.031421818233462045,
#    'cough': 0.0045896556804929335,
#    'covid-19': 0.036255736553572934,
#    'cytokine': 0.008594938181770026,
#    'd-dimer measurement': 0.004744308816666219,
#    'death': 0.011045041463964247,
#    'degradation': 0.002383621499518678,
#    'diabetes mellitus': 0.02823827042414508,
#    'diabetic ketoacidosis': 0.0026725939574367735,
#    'diarrhea, ctcae': 0.0038843959144780928,
#    'dipeptidyl peptidase 4': 0.022703469279651833,
#    'dna replication': 0.00401662804669848,
#    'dpp4i': 0.009123063051584357,
#    'dyspnea': 0.0009214330353024784,
#    'extracellular matrix': 0.0007502070473713358,
#    'fatigue': 0.0009214330353024784,
#    'fever': 0.001978117997950759,
#    'glucose': 0.0373373239662181,
#    'glucose metabolism disorder': 0.009006761507667771,
#    'glyburide': 0.02058169712301436,
#    'glycosylated hemoglobin measurement': 0.0033723864431790926,
#    'growth factor': 0.0010828815350642663,
#    'h1n1': 0.0018460304311648415,
#    'hcp': 6.530243115278357e-05,
#    'headache': 0.004211844925217239,
#    'heart': 0.006655584026259678,
#    'heart failure': 0.001129756362501045,
#    'high sensitivity c-reactive protein measurement': 0.0015416261532911668,
#    'hiv entry inhibitor': 0.003797932090242825,
#    'hmg-coa reductase inhibitor': 0.0016482495811937189,
#    'host cell': 0.00256936945470814,
#    'human': 0.01426719170091054,
#    'human dpp4': 0.0006633265192227697,
#    'human immunodeficiency virus': 0.00041765936057596727,
#    'human kidney organoids': 0.00022232297136891692,
#    'humoral immunity': 0.0009551013248966977,
#    'hyperglycemia': 0.010405301659739763,
#    'hypertension': 0.016046643542952505,
#    'hypoxia': 0.0018180916443721088,
#    'ibuprofen': 0.0048252870287190585,
#    'immune cell': 0.004502222825921624,
#    'immune response process': 0.0014390873098209334,
#    'infectious disorder': 0.02603045229280145,
#    'inflammation': 0.015451980372781645,
#    'influenza': 0.001967917087932946,
#    'insulin': 0.015702664400617895,
#    'insulin infusion': 0.00035269711494444796,
#    'insulin resistance': 0.0034849211808168834,
#    'interleukin': 0.0017510846793290188,
#    'interleukin 1 beta measurement': 0.006781603179777293,
#    'interleukin-19': 0.01077786521866382,
#    'interleukin-6': 0.009105368088308943,
#    'interleukin-8': 0.0037960215253299875,
#    'islet of langerhans': 0.0010113741192290203,
#    'iv': 0.0001719836805249858,
#    'janus bifrons': 0.0,
#    'kidney': 0.009158775062235214,
#    'leucopenia': 0.002837226347160995,
#    'leukopenia': 0.0,
#    'liver': 0.009581155527003792,
#    'lower respiratory tract infection': 0.007907646115315777,
#    'lung': 0.014260776930883243,
#    'lymphocyte': 0.004104256775405589,
#    'lymphopenia': 0.001728060655029333,
#    'm protein': 0.0008749669180820899,
#    'macrophage': 0.004898151052041066,
#    'mellitus': 0.0,
#    'metformin': 0.0008497609085040198,
#    'middle east respiratory syndrome': 0.003188979144861952,
#    'middle east respiratory syndrome coronavirus': 0.006860769882471508,
#    'millimole per liter': 0.0,
#    'molecule': 0.00231924394628949,
#    'mouse': 0.011283966859942589,
#    'multi-organ dysfunction': 0.0006008329695425134,
#    'muscle': 0.0007730473023580233,
#    'myalgia': 0.0007734480467541734,
#    'myocardium': 0.0006292021483381069,
#    'neoplasm': 0.0034907342213115937,
#    'nephropathy': 0.003174262828906012,
#    'neutrophil': 0.006107305774671061,
#    'obesity': 0.01799240816173776,
#    'oral cavity': 0.007057041440845085,
#    'organ': 0.0022913561297523252,
#    'oxygen': 0.001153080627558314,
#    'person': 0.004061612494094748,
#    'plasma': 0.005081664572127276,
#    'plasmid': 0.005337546930867222,
#    'pneumonia': 0.013185331948480383,
#    'prognosis': 0.0,
#    'proliferation': 0.004138444269769933,
#    'pulmonary': 0.021890141059828415,
#    'rbd': 0.001723467499167217,
#    'receptor binding': 0.0004334327683087759,
#    'renal': 0.003337558904864326,
#    'respiratory failure': 0.001414066426183902,
#    'respiratory system': 0.00562188381333231,
#    'sars coronavirus': 0.01600342751974006,
#    'sars-cov-2': 0.03200196500129228,
#    'saxagliptin': 0.001255417950334784,
#    'septicemia': 0.00024114854831181173,
#    'serum': 0.002086966535302325,
#    'serum ferritin': 0.0020610953356448003,
#    'severe acute respiratory syndrome': 0.0004730622203350349,
#    'shortness of breath visual analogue scale': 0.0004919135741532377,
#    'sitagliptin': 0.014414519186248661,
#    'sulfonylurea antidiabetic agent': 0.0012203735400739429,
#    'survival': 0.0021494901325805307,
#    't-lymphocyte': 0.008958583917413554,
#    'therapeutic corticosteroid': 0.0035505324776035274,
#    'thrombophilia': 0.0022194428127748126,
#    'tissue': 0.004132889965767883,
#    'transmembrane protein': 0.0032747154996986653,
#    'troponin t, cardiac muscle': 0.0,
#    'tumor necrosis factor': 0.004918344990328303,
#    'tzd': 0.0014853923510159434,
#    'vaccine': 0.0006070565929102022,
#    'vascular': 0.009511217216777643,
#    'vildagliptin': 0.0039057013902945056,
#    'viral': 0.02161496511143317,
#    'viral entry': 0.005880176609208339,
#    'viral infection': 0.008303253478017629,
#    'virus': 0.02379911748695524}},
#  'closeness': {'frequency': {'ace inhibitor': 0.4984025559105431,
#    'acetaminophen': 0.4051948051948052,
#    'acute lung injury': 0.5098039215686274,
#    'acute respiratory distress syndrome': 0.5416666666666666,
#    'adenosine': 0.5165562913907285,
#    'adipose tissue': 0.5288135593220339,
#    'angioedema': 0.48148148148148145,
#    'angiotensin ii receptor antagonist': 0.52,
#    'angiotensin-1': 0.5182724252491695,
#    'angiotensin-2': 0.5064935064935066,
#    'angiotensin-converting enzyme': 0.4419263456090652,
#    'angiotensin-converting enzyme 2': 0.5288135593220339,
#    'animal': 0.5148514851485149,
#    'apoptosis': 0.5182724252491695,
#    'bals r': 0.29213483146067415,
#    'basal': 0.47706422018348627,
#    'blood': 0.5591397849462365,
#    'blood vessel': 0.48,
#    'bradykinin': 0.4406779661016949,
#    'c-c motif chemokine 1': 0.513157894736842,
#    'c-reactive protein': 0.5114754098360655,
#    'cardiac failure': 0.49367088607594933,
#    'cardiovascular disorder': 0.5360824742268041,
#    'cardiovascular system': 0.5416666666666666,
#    'cd44 antigen': 0.4984025559105431,
#    'cellular secretion': 0.5288135593220339,
#    'cerebrovascular': 0.5,
#    'chemokine': 0.5473684210526316,
#    'chest pain': 0.52,
#    'chloroquine': 0.4285714285714286,
#    'chronic disease': 0.46428571428571425,
#    'chronic kidney disease': 0.4890282131661442,
#    'comorbidity': 0.43454038997214484,
#    'confounding factors': 0.50814332247557,
#    'coronaviridae': 0.5016077170418006,
#    'coronavirus': 0.5571428571428572,
#    'cough': 0.48,
#    'covid-19': 0.5288135593220339,
#    'cytokine': 0.5324232081911263,
#    'd-dimer measurement': 0.5064935064935066,
#    'death': 0.50814332247557,
#    'degradation': 0.48148148148148145,
#    'diabetes mellitus': 0.5379310344827586,
#    'diabetic ketoacidosis': 0.5,
#    'diarrhea, ctcae': 0.5064935064935066,
#    'dipeptidyl peptidase 4': 0.5360824742268041,
#    'dna replication': 0.5182724252491695,
#    'dpp4i': 0.5270270270270271,
#    'dyspnea': 0.475609756097561,
#    'extracellular matrix': 0.43333333333333335,
#    'fatigue': 0.475609756097561,
#    'fever': 0.49367088607594933,
#    'glucose': 0.5591397849462365,
#    'glucose metabolism disorder': 0.5416666666666666,
#    'glyburide': 0.5360824742268041,
#    'glycosylated hemoglobin measurement': 0.5148514851485149,
#    'growth factor': 0.5048543689320388,
#    'h1n1': 0.4984025559105431,
#    'hcp': 0.38902743142144636,
#    'headache': 0.5148514851485149,
#    'heart': 0.52,
#    'heart failure': 0.49367088607594933,
#    'high sensitivity c-reactive protein measurement': 0.47129909365558914,
#    'hiv entry inhibitor': 0.5182724252491695,
#    'hmg-coa reductase inhibitor': 0.5016077170418006,
#    'host cell': 0.4968152866242038,
#    'human': 0.5379310344827586,
#    'human dpp4': 0.48750000000000004,
#    'human immunodeficiency virus': 0.46846846846846846,
#    'human kidney organoids': 0.46987951807228917,
#    'humoral immunity': 0.48148148148148145,
#    'hyperglycemia': 0.5,
#    'hypertension': 0.5360824742268041,
#    'hypoxia': 0.5016077170418006,
#    'ibuprofen': 0.5114754098360655,
#    'immune cell': 0.4968152866242038,
#    'immune response process': 0.5,
#    'infectious disorder': 0.5454545454545454,
#    'inflammation': 0.5416666666666666,
#    'influenza': 0.4968152866242038,
#    'insulin': 0.5270270270270271,
#    'insulin infusion': 0.4469914040114613,
#    'insulin resistance': 0.5252525252525252,
#    'interleukin': 0.49367088607594933,
#    'interleukin 1 beta measurement': 0.5342465753424657,
#    'interleukin-19': 0.5379310344827586,
#    'interleukin-6': 0.5217391304347826,
#    'interleukin-8': 0.5114754098360655,
#    'islet of langerhans': 0.5048543689320388,
#    'iv': 0.430939226519337,
#    'janus bifrons': 0.27708703374777977,
#    'kidney': 0.5114754098360655,
#    'leucopenia': 0.48447204968944096,
#    'leukopenia': 0.3277310924369748,
#    'liver': 0.5473684210526316,
#    'lower respiratory tract infection': 0.5306122448979592,
#    'lung': 0.5306122448979592,
#    'lymphocyte': 0.5114754098360655,
#    'lymphopenia': 0.4629080118694362,
#    'm protein': 0.48,
#    'macrophage': 0.513157894736842,
#    'mellitus': 0.3482142857142857,
#    'metformin': 0.4921135646687697,
#    'middle east respiratory syndrome': 0.5048543689320388,
#    'middle east respiratory syndrome coronavirus': 0.5252525252525252,
#    'millimole per liter': 0.31451612903225806,
#    'molecule': 0.46567164179104475,
#    'mouse': 0.5397923875432526,
#    'multi-organ dysfunction': 0.48447204968944096,
#    'muscle': 0.48447204968944096,
#    'myalgia': 0.4419263456090652,
#    'myocardium': 0.48598130841121495,
#    'neoplasm': 0.5270270270270271,
#    'nephropathy': 0.5,
#    'neutrophil': 0.5306122448979592,
#    'obesity': 0.5571428571428572,
#    'oral cavity': 0.5252525252525252,
#    'organ': 0.48598130841121495,
#    'oxygen': 0.475609756097561,
#    'person': 0.5114754098360655,
#    'plasma': 0.52,
#    'plasmid': 0.52,
#    'pneumonia': 0.5324232081911263,
#    'prognosis': 0.2694300518134715,
#    'proliferation': 0.5165562913907285,
#    'pulmonary': 0.5611510791366907,
#    'rbd': 0.48750000000000004,
#    'receptor binding': 0.4508670520231214,
#    'renal': 0.48598130841121495,
#    'respiratory failure': 0.4890282131661442,
#    'respiratory system': 0.5016077170418006,
#    'sars coronavirus': 0.5182724252491695,
#    'sars-cov-2': 0.5416666666666666,
#    'saxagliptin': 0.4921135646687697,
#    'septicemia': 0.4406779661016949,
#    'serum': 0.50814332247557,
#    'serum ferritin': 0.48598130841121495,
#    'severe acute respiratory syndrome': 0.4629080118694362,
#    'shortness of breath visual analogue scale': 0.4785276073619632,
#    'sitagliptin': 0.5379310344827586,
#    'sulfonylurea antidiabetic agent': 0.5016077170418006,
#    'survival': 0.5048543689320388,
#    't-lymphocyte': 0.5342465753424657,
#    'therapeutic corticosteroid': 0.5148514851485149,
#    'thrombophilia': 0.5,
#    'tissue': 0.5098039215686274,
#    'transmembrane protein': 0.5148514851485149,
#    'troponin t, cardiac muscle': 0.3277310924369748,
#    'tumor necrosis factor': 0.5165562913907285,
#    'tzd': 0.50814332247557,
#    'vaccine': 0.4785276073619632,
#    'vascular': 0.5114754098360655,
#    'vildagliptin': 0.5032258064516129,
#    'viral': 0.5591397849462365,
#    'viral entry': 0.5234899328859061,
#    'viral infection': 0.5306122448979592,
#    'virus': 0.5571428571428572}}}

# %% [markdown]
# ## Community detection

# %% [markdown]
# _Community detection_ methods partition the network into clusters of densely connected nodes in a way that nodes in the same community are more connected between themselves relatively to the nodes in different communities.
#
# The _modularity_ measure quantifies how well the communities are 'separated' (https://en.wikipedia.org/wiki/Modularity_(networks)).

# %%
print("Paper-based graph")
print("-----------------")
_ = detect_communities(paper_comention_network, weight="frequency", set_attr="community")
_ = detect_communities(paper_comention_network, weight="npmi", set_attr="community_npmi")
print()

print("Section-based graph")
print("-------------------")
_ = detect_communities(section_comention_network, weight="frequency", set_attr="community")
_ = detect_communities(section_comention_network, weight="npmi", set_attr="community_npmi")
print()

print("Paragraph-based graph")
print("---------------------")
_ = detect_communities(paragraph_comention_network, weight="frequency", set_attr="community")
_ = detect_communities(paragraph_comention_network, weight="npmi", set_attr="community_npmi")
print()

# %% [markdown]
# In the example above we can see that the best partition is performed on the paragraph-based network using the NPMI edge weight (resulting in the modularity 0.34).

# %% [markdown]
# ## Export network and the computed metrics

# %%
# Save graph nodes as a pickled pandas.DataFrame
save_network(paragraph_comention_network, "data/literature_comention")

# %%
# Save the graph for Gephi import.
save_to_gephi(
    paragraph_comention_network, "data/gephi_literature_comention", 
    node_attr_mapping = {
        "degree_frequency": "Degree",
        "pagerank_frequency": "PageRank",
        "betweenness_distance_npmi": "Betweenness",
        "community_npmi": "Community"
    },
    edge_attr_mapping={
        "npmi": "Weight"
    })

# %% [markdown]
# The representation of the network saved above can be imported into Gephi for producing graph visualizations, as in the following example:
#
# In the figures below colors represent communities detected using the NPMI weight, node sizes are proportional to the PageRank of nodes and edge thickness to the NPMI values.
#
# **Full network**
# <img src="./figures/literature/full_network.png" alt="Literature co-occurrence network" style="width: 400px;"/>
#
# **Community "Symptoms and comorbidities"**
# <img src="./figures/literature/covid_19_comorbidities.png" alt="Drawing" style="width: 400px;"/>
#
# **Community "Viral biology"**
# <img src="./figures/literature/virus.png" alt="Drawing" style="width: 600px;"/>
#
# **Community "Immunity"**
# <img src="./figures/literature/immunity.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# ## Minimum spanning trees

# %% [markdown]
# A _minimum spanning tree_ of a network is given by a subset of edges that make the network connected ($n - 1$ edges connecting $n$ nodes). Its weighted version minimizes not only the number of edges included in the tree, but the total edge weight.
#
# In the following example we compute a minimum spanning tree minimizing the NPMI-based distance weight of the network edges.

# %%
tree = minimum_spanning_tree(paragraph_comention_network, weight="distance_npmi")

# %%
save_to_gephi(
    tree, "data/gephi_literature_spanning_tree", 
    node_attr_mapping = {
        "degree_frequency": "Degree",
        "pagerank_frequency": "PageRank",
        "betweenness_distance_npmi": "Betweenness",
        "community_npmi": "Community"
    },
    edge_attr_mapping={
        "npmi": "Weight"
    })

# %% [markdown]
# The representation of the network saved above can be imported into Gephi for producing graph visualizations, as in the following example:
#
# In the figures below colors represent communities detected using the NPMI weight, node sizes are proportional to the PageRank of nodes and edge thickness to the NPMI values.
#
# **Full network**
# <img src="./figures/literature/tree.png" alt="Literature co-occurrence MST" style="width: 400px;"/>
#
# **Zoom into "covid-19"**
# <img src="./figures/literature/tree_covid-19.png" alt="Drawing" style="width: 700px;"/>

# %% [markdown]
# ## Shortest path search

# %% [markdown]
# The _shortest path search problem_ consisits in finding a sequence of edges from the source node to the target node that minimizes the cumulative weight (or distance) associated to the edges.

# %%
path = single_shortest_path(paragraph_comention_network, "lung", "sars-cov-2")
pretty_print_paths([path])

# %% [markdown]
# The cell above illustrates that the single shortest path form 'lung' and 'sars-cov-2' consists of the direct edge between them.
#
# We adapt this problem to the literature exploration task, i.e. having fixed the source and the target concepts (the relation here is actually symmetric as the edges of our network are undirected), we would like to find a _set_ of $n$ shortest paths between them. Moreover, we would like these paths to be _indirect_ (not to include the direct edge from the source to the target). In the following examples we use mutual-information-based edge weights to perform our literature exploration.
#
# The library includes two strategies for finding such $n$ shortest paths. The first strategy uses Yen's algorithm for finding $n$ loopless shortest paths from the source to the target (https://en.wikipedia.org/wiki/Yen%27s_algorithm).

# %%
paths = top_n_paths(
    paragraph_comention_network, "lung", "sars-cov-2", n=10,
    distance="distance_npmi", strategy="yen")

# %%
pretty_print_paths(paths)

# %% [markdown]
# The second, _naive_, strategy is suitable in the scenarios when our networks are large and highly dense (then the performance of Yen's algorithm degragates as the number of edges is approaching $O(N^2)$ with $N$ being the number of nodes).
#
# This strategy simply finds _all_ the indirect shortest paths from the source to the target (in dense graphs the most common such paths are of length 2, i.e. `source <-> intermediary <-> target`, and therefore, the number of such path is roughly proportional to the number of nodes in the network). Then, the cumulative distance score is computed for every path and the top $n$ paths with the best score are selected.

# %%
 paths = top_n_paths(
    paragraph_comention_network, "lung", "sars-cov-2", n=10,
    distance="distance_npmi",
    strategy="naive")

# %%
pretty_print_paths(paths)

# %% [markdown]
# We can also look for shortest paths in the minimum spanning tree constructed using the mutual-information-based scores (there is exactly one such path).

# %%
path = single_shortest_path(tree, "lung", "sars-cov-2")
pretty_print_paths([path])

# %% [markdown]
# The library provides an additional utility for finding _tripaths_, paths of the shape `source <-> intermediary <-> target`. Setting the parameter `intersecting` to `False` we can ensure that the entities the sets of entities discovered on the paths `source <-> intermediary` and `intermediary <-> target` do not overlap.

# %%
path_a_b, path_b_c =  top_n_tripaths(
    paper_comention_network, "lung", "glucose", "sars-cov-2", 10,
    strategy="yen", distance="distance_npmi", intersecting=False)

# %%
pretty_print_tripaths("lung", "glucose", "sars-cov-2", 10, path_a_b, path_b_c)

# %% [markdown]
# ## Nested path search

# %% [markdown]
# To explore the space of co-occurring terms in depth, we can run the path search procedure presented above in a _nested fashion_. For each edge $e_1, e_2, ..., e_n$ encountered on a path from the source to the target  from, we can
# further expand it into $n$ shortest paths between each pair of successive entities (i.e. paths between $e_1$ and $e_2$, $e_2$ and $e_3$, etc.).

# %%
paths = top_n_nested_paths(
    paragraph_comention_network, "lung", "glucose",
    n=10, nested_n=2, depth=2, distance="distance_npmi",
    strategy="naive")

# %%
print(paths)

# %% [markdown]
# We can now visualize the subnetwork constructed using the nodes and the edges discovered during our nested path search.

# %%
summary_graph = graph_from_paths(paths, source_graph=paper_comention_network)

# %%
print("Number of nodes: ", summary_graph.number_of_nodes())
print("Number of edges: ", summary_graph.number_of_edges())

# %%
# Save the graph for Gephi import.
save_to_gephi(
    summary_graph, "data/gephi_literature_path_graph", 
    node_attr_mapping = {
        "degree_frequency": "Degree",
        "pagerank_frequency": "PageRank",
        "betweenness_distance_npmi": "Betweenness",
        "community_npmi": "Community"
    },
    edge_attr_mapping={
        "npmi": "Weight"
    })

# %% [markdown]
# The resulting graph visualized with Gephi
# <img src="./figures/literature/path_graph.png" alt="Literature co-occurrence network" style="width: 800px;"/>
